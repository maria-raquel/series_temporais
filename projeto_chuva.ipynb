# 1       34.5    60.70    242.50    389.90
# 2       80.2    84.80     72.70    152.10
# 3       28.4   173.90    100.20    289.80
# 4       52.1    80.10     88.00    236.70
# 5       97.2   206.80    116.30    149.80
# 6      101.4   168.00     67.30    237.90
# 7      150.6   219.60    145.04    211.70
# 8      210.1   134.10    125.50    170.50
# 9        1.8   147.60     86.60    276.30
# 10      44.2   202.60    115.10    236.04
# 11     179.4   179.80     87.40    243.90
# 12     118.0   151.80    236.30    217.40
# 13      99.5   203.10     41.50    198.40
# 14      76.9    64.50     76.00    100.40
# 15     120.3   105.50    322.00    281.00
# 16      82.3   213.10    181.60    292.90
# 17      84.0   143.90    201.40    263.70
# 18      41.5   176.70    133.00     89.90
# 19      13.8   120.60    215.50    181.00
# 20     150.3   195.30     96.60    140.10
# 21      86.2    71.90    175.00    353.30
# 22      27.4   167.20    211.70    268.70
# 23      49.9   144.30    125.40    152.90
# 24     198.9   157.40    237.20    294.50
# 25     100.4    73.80    129.20    234.70
# 26      10.7   218.20     73.40    393.70
# 27      31.9    93.90    154.00    623.20
# 28      45.1   110.70     76.60    139.90
# 29      82.1    23.80    209.30    258.00
# 30     280.9   139.89    145.04    221.90
# 31      29.1   116.90    181.20    129.20
# 32      12.0   121.20    174.40    169.60
# 33      72.9   203.40    134.10    258.00
# 34      73.7    75.90    170.80    249.00
# 35      22.9   213.90    162.10    236.04

# %% [markdown]
# ## **Criação da Série**

# %%
chuva2 = chuva.drop(columns='Ano')
chuva2.head()
# Out:
#    Janeiro  Fevereiro  Março  Abril   Maio  Junho  Julho  Agosto  Setembro  \
# 0    184.9      242.9  230.0   59.0  126.2   14.6    4.0   21.80     126.1
# 1    199.6      221.0  218.7  106.5  113.1    3.9   30.3   27.85      34.5
# 2    525.8      249.3  161.3   98.1  293.8  183.9   11.8   30.90      80.2
# 3    268.7      224.4  189.2  175.1  224.9   58.6    1.3    0.20      28.4
# 4    312.9      344.3  288.2   66.3   21.7   52.5  150.1   32.90      52.1
#
#    Outubro  Novembro  Dezembro
# 0     71.1     111.3     155.2
# 1     60.7     242.5     389.9
# 2     84.8      72.7     152.1
# 3    173.9     100.2     289.8
# 4     80.1      88.0     236.7

# %%
# Transformar em Array???
chuva3 = chuva2.values
chuva3
# Out:
# array([[1.8490e+02, 2.4290e+02, 2.3000e+02, 5.9000e+01, 1.2620e+02,
#         1.4600e+01, 4.0000e+00, 2.1800e+01, 1.2610e+02, 7.1100e+01,
#         1.1130e+02, 1.5520e+02],
#        [1.9960e+02, 2.2100e+02, 2.1870e+02, 1.0650e+02, 1.1310e+02,
#         3.9000e+00, 3.0300e+01, 2.7850e+01, 3.4500e+01, 6.0700e+01,
#         2.4250e+02, 3.8990e+02],
#        [5.2580e+02, 2.4930e+02, 1.6130e+02, 9.8100e+01, 2.9380e+02,
#         1.8390e+02, 1.1800e+01, 3.0900e+01, 8.0200e+01, 8.4800e+01,
#         7.2700e+01, 1.5210e+02],
#        [2.6870e+02, 2.2440e+02, 1.8920e+02, 1.7510e+02, 2.2490e+02,
#         5.8600e+01, 1.3000e+00, 2.0000e-01, 2.8400e+01, 1.7390e+02,
 85.0, 31.0, 31.7, 26.9, 82.3, 213.1, 181.6, 292.9, 300.6, 173.6, 354.8, 95.3, 137.6, 2.3, 23.0, 41.5, 84.0, 143.9, 201.4, 263.7, 443.4, 141.5, 250.2, 45.5, 36.6, 20.7, 24.5, 27.6, 41.5, 176.7, 133.0, 89.9, 188.8, 316.9, 127.2, 160.5, 77.4, 75.6, 105.6, 2.2, 13.8, 120.6, 215.5, 181.0, 378.3, 95.9, 202.1, 137.3, 177.1, 35.1, 39.8, 11.5, 150.3, 195.3, 96.6, 140.1, 230.9, 223.5, 407.9, 65.4, 23.7, 34.8, 78.6, 9.2, 86.2, 71.9, 175.0, 353.3, 208.7, 301.0, 240.2, 67.6, 63.1, 17.2, 134.3, 0.1, 27.4, 167.2, 211.7, 268.7, 388.0, 136.4, 332.8, 123.6, 80.9, 55.7, 0.0, 52.5, 49.9, 144.3, 125.4, 152.9, 356.4, 145.0, 73.6, 75.3, 58.1, 28.3, 157.7, 27.85, 198.9, 157.4, 237.2, 294.5, 549.1, 175.4, 258.9, 116.4, 52.8, 20.2, 78.4, 1.2, 100.4, 73.8, 129.2, 234.7, 428.4, 349.5, 265.1, 142.0, 40.1, 81.3, 1.5, 49.7, 10.7, 218.2, 73.4, 393.7, 401.5, 226.0, 165.9, 149.1, 82.4, 59.66, 105.5, 3.7, 31.9, 93.9, 154.0, 623.2, 321.7, 372.1, 175.0, 103.4, 39.4, 210.9, 168.8, 15.3, 45.1, 110.7, 76.6, 139.9, 189.7, 236.1, 222.9, 110.2, 71.0, 11.5, 51.9, 20.5, 82.1, 23.8, 209.3, 258.0, 249.3, 303.5, 265.9, 100.4, 87.2, 25.4, 62.7, 40.5, 280.9, 139.89, 145.04, 221.9, 242.8, 225.2, 288.1, 92.2, 141.4, 207.3, 0.0, 82.2, 29.1, 116.9, 181.2, 129.2, 305.79, 249.3, 120.8, 156.3, 166.1, 101.6, 0.2, 53.4, 12.0, 121.2, 174.4, 169.6, 238.2, 84.5, 227.97, 66.4, 25.8, 15.0, 20.5, 27.85, 72.9, 203.4, 134.1, 258.0, 305.79, 315.5, 318.5, 172.3, 97.3, 59.0, 195.1, 6.7, 73.7, 75.9, 170.8, 249.0, 408.1, 249.3, 95.5, 5.6, 13.7, 163.8, 54.6, 62.1, 22.9, 213.9, 162.1, 236.04]

# %%
indice = pd.date_range('1985', periods = len(chuva4), freq = 'M')
indice
# Out:
# DatetimeIndex(['1985-01-31', '1985-02-28', '1985-03-31', '1985-04-30',
#                '1985-05-31', '1985-06-30', '1985-07-31', '1985-08-31',
#                '1985-09-30', '1985-10-31',
#                ...
#                '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30',
#                '2020-07-31', '2020-08-31', '2020-09-30', '2020-10-31',
#                '2020-11-30', '2020-12-31'],
#               dtype='datetime64[ns]', length=432, freq='M')

# %%
serie = pd.Series(chuva4, index = indice)
serie
# Out:
# 1985-01-31    184.90
# 1985-02-28    242.90
# 1985-03-31    230.00
# 1985-04-30     59.00
# 1985-05-31    126.20
#                ...
# 2020-08-31     62.10
# 2020-09-30     22.90
# 2020-10-31    213.90
# 2020-11-30    162.10
# 2020-12-31    236.04
# Freq: M, Length: 432, dtype: float64

# %%
serie.plot()
plt.show()

# %% [markdown]
# ## **Análise e Preparação da Série**

# %% [markdown]
# ### **Média Móvel**

# %%
media_movel = serie.rolling(window = 6)
media_movel = media_movel.mean()

# %%
plt.plot(media_movel);

# %%
plt.plot(serie, label='Série Real')
plt.plot(media_movel,color='red', label='Média Móvel 6 meses')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Decomposição**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposicao = seasonal_decompose(serie)

# %%
decomposicao.plot()

# %% [markdown]
# ### **Normalidade e Transformação**

# %%
import scipy.stats as stats

# %%
stats.probplot(serie, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %% [markdown]
# **Teste Shapiro-Wilk**
#
# CRITÉRIOS:
#
# NÍVEL DE SIGNIFICÂNCIA DE 0,05 ou 5% (MAIS UTILIZADO)
#
# Ho = distribuição normal p > 0,05
#
# Ha = distribuição não normal p <= 0,05

# %%
e, p = stats.shapiro(serie)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 0.9260320067405701
# p-valor: 9.108177130264308e-14

# %%
# Transformação por log (Diminuir variância e melhorar normalidade)
serie2 = np.log(serie)
serie2
# Out:
# /home/raquel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 1985-01-31    5.219815
# 1985-02-28    5.492650
# 1985-03-31    5.438079
# 1985-04-30    4.077537
# 1985-05-31    4.837868
#                 ...
# 2020-08-31    4.128746
# 2020-09-30    3.131137
# 2020-10-31    5.365509
# 2020-11-30    5.088213
# 2020-12-31    5.464001
# Freq: M, Length: 432, dtype: float64

# %%
e, p = stats.shapiro(serie2)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: nan
# p-valor: 1.0

# %%
# Transformação por raiz cúbica (quando possui dados com valor zero ou negativos)
serie3 = np.sign(serie)*abs(serie)**(1/3)
serie3
# Out:
# 1985-01-31    5.696992
# 1985-02-28    6.239395
# 1985-03-31    6.126926
# 1985-04-30    3.892996
# 1985-05-31    5.015949
#                 ...
# 2020-08-31    3.960018
# 2020-09-30    2.839739
# 2020-10-31    5.980492
# 2020-11-30    5.452483
# 2020-12-31    6.180096
# Freq: M, Length: 432, dtype: float64

# %%
stats.probplot(serie3, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
e, p =stats.shapiro(serie3)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 0.9826487898826599
# p-valor: 4.832293780054897e-05

# %%
import seaborn as sns
sns.distplot(serie);
# Out:
# /home/raquel/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(serie3);
# Out:
# /home/raquel/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Posso tentar mais vezes???? Não é recomendado, pois não adianta.
serie4 = (serie3)**(1/3)
serie4
# Out:
# 1985-01-31    1.786002
# 1985-02-28    1.840973
# 1985-03-31    1.829845
# 1985-04-30    1.573118
# 1985-05-31    1.711792
#                 ...
# 2020-08-31    1.582094
# 2020-09-30    1.416096
# 2020-10-31    1.815149
# 2020-11-30    1.760076
# 2020-12-31    1.835123
# Freq: M, Length: 432, dtype: float64

# %% [markdown]
# ### **Estacionaridade**

# %%
import statsmodels.tsa.stattools

# %% [markdown]
# Teste KPSS (Kwiatkowski-Phillips-Schmidt-Shin)
#
# Ho = não é estacionário: estatística do teste > valor crítico
#
# Ha = é estacionário:  estatística do teste < valor crítico

# %%
kpss = statsmodels.tsa.stattools.kpss(serie3)
print('Estatítica do teste: {:.4f}'.format(kpss[0]))
print('p_valor: {:.4f}'.format(kpss[1]))
print('Valores Críticos:')
for chave, valor in kpss[3].items():
   print('{}: {:.4f}'.format(chave, valor))
# Out:
# Estatítica do teste: 0.0199
# p_valor: 0.1000
# Valores Críticos:
# 10%: 0.3470
# 5%: 0.4630
# 2.5%: 0.5740
# 1%: 0.7390
# /tmp/ipykernel_29815/1748613426.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss = statsmodels.tsa.stattools.kpss(serie3)

# %%
# Caso não fosse estacionária poderia tentar fazer a diferenciação:
# serie5 = np.diff(serie3)

# %% [markdown]
# ### **Autocorrelação**

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(serie3, lags=20)
plt.show()

# %%
plot_pacf(serie, lags=20)
plt.show()

# %% [markdown]
# A série é autocorrelacionada, mas não tem problema, pois esse é um pressuposto da análise dos resíduos dos modelos de séries temporais.

# %% [markdown]
# ## **Modelo AR**

# %% [markdown]
# Modelo arima:(p,d,q)
#
# Modelo ar: (p,0,0)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
modelo_ar = ARIMA(serie3, order = (9,0,0))

# %%
resultado = modelo_ar.fit()
print(resultado.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  432
# Model:                 ARIMA(9, 0, 0)   Log Likelihood                -657.961
# Date:                Tue, 29 Aug 2023   AIC                           1337.922
# Time:                        20:33:51   BIC                           1382.675
# Sample:                    01-31-1985   HQIC                          1355.591
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7812      0.036    134.373      0.000       4.711       4.851
# ar.L1          0.1497      0.045      3.299      0.001       0.061       0.239
# ar.L2          0.0648      0.055      1.187      0.235      -0.042       0.172
# ar.L3         -0.1109      0.056     -1.968      0.049      -0.221      -0.000
# ar.L4         -0.0962      0.051     -1.877      0.061      -0.197       0.004
# ar.L5         -0.1848      0.052     -3.547      0.000      -0.287      -0.083
# ar.L6         -0.2420      0.052     -4.664      0.000      -0.344      -0.140
# ar.L7         -0.2411      0.051     -4.689      0.000      -0.342      -0.140
# ar.L8         -0.0546      0.053     -1.037      0.300      -0.158       0.049
# ar.L9          0.0132      0.051      0.260      0.795      -0.087       0.113
# sigma2         1.2249      0.074     16.605      0.000       1.080       1.369
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                17.97
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.26   Skew:                            -0.32
# Prob(H) (two-sided):                  0.17   Kurtosis:                         3.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
plot_acf(serie3, lags=20)
plt.show()

# %% [markdown]
# Melhor AIC: 1337.922 = (9,0,0)

# %% [markdown]
# ### **Análise dos Resíduos**

# %%
residuos = resultado.resid
residuos
# Out:
# 1985-01-31    0.915755
# 1985-02-28    1.009225
# 1985-03-31    0.621499
# 1985-04-30   -1.541707
# 1985-05-31    0.749286
#                 ...
# 2020-08-31   -0.237112
# 2020-09-30   -2.025517
# 2020-10-31    0.328097
# 2020-11-30   -0.775205
# 2020-12-31    0.173581
# Freq: M, Length: 432, dtype: float64

# %%
residuos.plot()
plt.show()

# %% [markdown]
# **Normalidade**

# %%
stats.probplot(residuos, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
e, p = stats.shapiro(residuos)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 0.9866629838943481
# p-valor: 0.0005366815021261573

# %%
import seaborn as sns
sns.distplot(residuos);
# Out:
# /home/raquel/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Autocorrelação**

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(residuos, lags=20)
plt.show()

# %%
plot_pacf(residuos, lags=20)
plt.show()

# %%
plt.plot(serie3, label='Série Real')
plt.plot(serie3-residuos,color='red', label='Resíduos')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Previsão**

# %%
resultado.fittedvalues
# Out:
# 1985-01-31    4.781238
# 1985-02-28    5.230171
# 1985-03-31    5.505427
# 1985-04-30    5.434703
# 1985-05-31    4.266663
#                 ...
# 2020-08-31    4.197130
# 2020-09-30    4.865256
# 2020-10-31    5.652395
# 2020-11-30    6.227689
# 2020-12-31    6.006515
# Freq: M, Length: 432, dtype: float64

# %%
previsao = resultado.predict(431, end=443)
previsao
# Out:
# 2020-12-31    6.006515
# 2021-01-31    5.402718
# 2021-02-28    5.501531
# 2021-03-31    5.218810
# 2021-04-30    4.775558
# 2021-05-31    4.053952
# 2021-06-30    3.847772
# 2021-07-31    3.911298
# 2021-08-31    4.199248
# 2021-09-30    4.517324
# 2021-10-31    4.889518
# 2021-11-30    5.264147
# 2021-12-31    5.513972
# Freq: M, Name: predicted_mean, dtype: float64

# %%
previsao2 = resultado.forecast(12)
previsao2
# Out:
# 2021-01-31    5.402718
# 2021-02-28    5.501531
# 2021-03-31    5.218810
# 2021-04-30    4.775558
# 2021-05-31    4.053952
# 2021-06-30    3.847772
# 2021-07-31    3.911298
# 2021-08-31    4.199248
# 2021-09-30    4.517324
# 2021-10-31    4.889518
# 2021-11-30    5.264147
# 2021-12-31    5.513972
# Freq: M, Name: predicted_mean, dtype: float64

# %%
previsao2[0]
# Out:
# 5.4027177289252055

# %%
plt.plot(serie3,color='yellow', label='Série Real')
plt.plot(previsao,color='blue', label='Previsão')
plt.plot(serie3-residuos,color='red', label='Resíduos')
plt.legend(loc='best')
plt.show()

# %%
prev_escala = pd.DataFrame(previsao ** 3, columns=['Previsão_AR'])
prev_escala
# Out:
# Empty DataFrame
# Columns: [Previsão_AR]
# Index: []

# %%
pd.concat([serie,prev_escala]).plot();

# %% [markdown]
# ## **Modelo MA**

# %% [markdown]
# Modelo arima:(p,d,q)
#
# Modelo ma: (0,0,q)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
modelo_ma = ARIMA(serie3, order = (0,0,8))

# %%
resultado_ma = modelo_ma.fit()
print(resultado_ma.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  432
# Model:                 ARIMA(0, 0, 8)   Log Likelihood                -695.848
# Date:                Tue, 29 Aug 2023   AIC                           1411.696
# Time:                        20:33:58   BIC                           1452.381
# Sample:                    01-31-1985   HQIC                          1427.758
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7863      0.028    172.577      0.000       4.732       4.841
# ma.L1          0.3130      0.051      6.129      0.000       0.213       0.413
# ma.L2          0.2280      0.051      4.501      0.000       0.129       0.327
# ma.L3         -0.0250      0.052     -0.479      0.632      -0.128       0.077
# ma.L4         -0.1083      0.050     -2.155      0.031      -0.207      -0.010
# ma.L5         -0.2183      0.050     -4.334      0.000      -0.317      -0.120
# ma.L6         -0.3098      0.050     -6.146      0.000      -0.409      -0.211
# ma.L7         -0.3396      0.051     -6.595      0.000      -0.441      -0.239
# ma.L8         -0.1237      0.051     -2.425      0.015      -0.224      -0.024
# sigma2         1.4631      0.095     15.430      0.000       1.277       1.649
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                35.13
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.22   Skew:                            -0.62
# Prob(H) (two-sided):                  0.23   Kurtosis:                         3.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Modelo AR: AIC = 1337.922 (9,0,0)
#
# Modelo MA: AIC = 1411.696 (0,0,8)

# %% [markdown]
# ### **Análise dos Resíduos**

# %%
residuos_ma = resultado_ma.resid

# %%
residuos_ma.plot()
plt.show()

# %% [markdown]
# **Normalidade**

# %%
stats.probplot(residuos_ma, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
e, p = stats.shapiro(residuos_ma)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 0.9771444797515869
# p-valor: 2.5968902264139615e-06

# %%
import seaborn as sns
sns.distplot(residuos_ma);
# Out:
# /home/raquel/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Autocorrelação**

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(residuos_ma, lags=30)
plt.show()

# %%
plot_pacf(residuos_ma, lags=30)
plt.show()

# %%
plt.plot(serie3, label='Série Real')
plt.plot(serie3-residuos_ma,color='red', label='Resíduos')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Previsão**

# %%
resultado_ma.fittedvalues
# Out:
# 1985-01-31    4.786255
# 1985-02-28    5.179211
# 1985-03-31    5.432528
# 1985-04-30    5.379936
# 1985-05-31    4.341617
#                 ...
# 2020-08-31    4.721012
# 2020-09-30    4.879099
# 2020-10-31    4.950800
# 2020-11-30    5.364027
# 2020-12-31    5.058304
# Freq: M, Length: 432, dtype: float64

# %%
previsao_ma = resultado_ma.predict(start=431, end=443)
previsao_ma
# Out:
# 2020-12-31    5.058304
# 2021-01-31    4.956918
# 2021-02-28    5.533746
# 2021-03-31    5.497440
# 2021-04-30    5.113150
# 2021-05-31    4.416556
# 2021-06-30    4.281338
# 2021-07-31    4.394365
# 2021-08-31    4.647503
# 2021-09-30    4.786255
# 2021-10-31    4.786255
# 2021-11-30    4.786255
# 2021-12-31    4.786255
# Freq: M, Name: predicted_mean, dtype: float64

# %%
plt.plot(serie3,color='yellow', label='Série Real')
plt.plot(previsao_ma,color='blue', label='Previsão')
plt.plot(serie3-residuos_ma,color='red', label='Resíduos')
plt.legend(loc='best')
plt.show()

# %%
prev_escala_ma = pd.DataFrame(previsao_ma ** 3, columns=['Previsão_MA'])
prev_escala_ma
# Out:
# Empty DataFrame
# Columns: [Previsão_MA]
# Index: []

# %%
pd.concat([serie,prev_escala_ma]).plot();

# %% [markdown]
# ## **Modelo ARMA**

# %% [markdown]
# Modelo arima:(p,d,q)
#
# Modelo arma: (p,0,q)

# %% [markdown]
# Modelo AR: AIC = 1337.922 (9,0,0)
#
# Modelo MA: AIC = 1411.696 (0,0,8)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
modelo_arma = ARIMA(serie3, order = (10,0,2))

# %%
resultado_arma = modelo_arma.fit()
print(resultado_arma.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  432
# Model:                ARIMA(10, 0, 2)   Log Likelihood                -653.584
# Date:                Tue, 29 Aug 2023   AIC                           1335.169
# Time:                        20:34:08   BIC                           1392.126
# Sample:                    01-31-1985   HQIC                          1357.655
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7869      0.036    134.796      0.000       4.717       4.857
# ar.L1         -0.7022      0.076     -9.285      0.000      -0.850      -0.554
# ar.L2         -0.6851      0.087     -7.906      0.000      -0.855      -0.515
# ar.L3          0.0910      0.065      1.402      0.161      -0.036       0.218
# ar.L4         -0.1340      0.061     -2.201      0.028      -0.253      -0.015
# ar.L5         -0.3793      0.059     -6.463      0.000      -0.494      -0.264
# ar.L6         -0.5000      0.057     -8.699      0.000      -0.613      -0.387
# ar.L7         -0.6223      0.061    -10.237      0.000      -0.741      -0.503
# ar.L8         -0.4768      0.072     -6.657      0.000      -0.617      -0.336
# ar.L9         -0.2109      0.070     -3.031      0.002      -0.347      -0.075
# ar.L10        -0.0683      0.054     -1.261      0.207      -0.174       0.038
# ma.L1          0.8720      0.057     15.371      0.000       0.761       0.983
# ma.L2          0.9239      0.056     16.613      0.000       0.815       1.033
# sigma2         1.1952      0.075     15.990      0.000       1.049       1.342
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                16.90
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.25   Skew:                            -0.32
# Prob(H) (two-sided):                  0.19   Kurtosis:                         3.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /home/raquel/.local/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# Modelo AR: AIC = 1337.922 (9,0,0)
#
# Modelo MA: AIC = 1411.696 (0,0,8)
#
# Modelo ARMA: Melhor AIC = 1273.766 (10,0,2)

# %% [markdown]
# ### **Análise dos Resíduos**

# %%
residuos_arma = resultado_arma.resid

# %%
residuos_arma.plot()
plt.show()

# %% [markdown]
# **Normalidade**

# %%
stats.probplot(residuos_arma, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
e, p = stats.shapiro(residuos_arma)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 0.9870170950889587
# p-valor: 0.0006722825346514583

# %%
import seaborn as sns
sns.distplot(residuos_arma);
# Out:
# /home/raquel/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Autocorrelação**

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(residuos_arma, lags=30)
plt.show()

# %%
plot_pacf(residuos_arma, lags=30)
plt.show()

# %%
plt.plot(serie3, label='Série Real')
plt.plot(serie3-residuos_arma,color='red', label='Resíduos')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Previsão**

# %%
resultado_arma.fittedvalues
# Out:
# 1985-01-31    4.786897
# 1985-02-28    5.256810
# 1985-03-31    5.543157
# 1985-04-30    5.470240
# 1985-05-31    4.249731
#                 ...
# 2020-08-31    4.067745
# 2020-09-30    5.100187
# 2020-10-31    5.639916
# 2020-11-30    5.966157
# 2020-12-31    6.204855
# Freq: M, Length: 432, dtype: float64

# %%
previsao_arma = resultado_arma.predict(start=431, end=455)
previsao_arma
# Out:
# 2020-12-31    6.204855
# 2021-01-31    5.401541
# 2021-02-28    5.432694
# 2021-03-31    5.478032
# 2021-04-30    4.647874
# 2021-05-31    3.954045
# 2021-06-30    3.997361
# 2021-07-31    3.951215
# 2021-08-31    4.003741
# 2021-09-30    4.622050
# 2021-10-31    4.891565
# 2021-11-30    5.161755
# 2021-12-31    5.648389
# 2022-01-31    5.542238
# 2022-02-28    5.222144
# 2022-03-31    5.143894
# 2022-04-30    4.702968
# 2022-05-31    4.261145
# 2022-06-30    4.275554
# 2022-07-31    4.182240
# 2022-08-31    4.205139
# 2022-09-30    4.648614
# 2022-10-31    4.889620
# 2022-11-30    5.033058
# 2022-12-31    5.356258
# Freq: M, Name: predicted_mean, dtype: float64

# %%
plt.plot(serie3,color='red', label='Série Real')
plt.plot(previsao_arma,color='blue', label='Previsão')
plt.plot(serie3-residuos_arma,color='yellow', label='Resíduos')
plt.legend(loc='best')
plt.show()

# %%
prev_escala_arma = pd.DataFrame(previsao_arma ** 3, columns=['Previsão_ARMA'])
prev_escala_arma
# Out:
# Empty DataFrame
# Columns: [Previsão_ARMA]
# Index: []

# %%
pd.concat([serie,prev_escala_arma]).plot();

# %% [markdown]
# ## **Modelo ARIMA**

# %% [markdown]
# Modelo arima:(p,d,q)

# %% [markdown]
# Modelo AR: AIC = 1337.922 (9,0,0)
#
# Modelo MA: Melhor AIC = 1411.696 (0,0,8)
#
# Modelo ARMA: Melhor AIC = 1273.766 (10,0,2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
modelo_arima = ARIMA(serie3, order = (10,1,2))

# %%
resultado_arima = modelo_arima.fit()
print(resultado_arima.summary())
# Out:
# /home/raquel/.local/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  432
# Model:                ARIMA(10, 1, 2)   Log Likelihood                -650.236
# Date:                Tue, 29 Aug 2023   AIC                           1326.472
# Time:                        20:34:15   BIC                           1379.331
# Sample:                    01-31-1985   HQIC                          1347.343
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7035      0.068     10.410      0.000       0.571       0.836
# ar.L2         -0.2223      0.067     -3.336      0.001      -0.353      -0.092
# ar.L3         -0.3099      0.074     -4.184      0.000      -0.455      -0.165
# ar.L4         -0.1093      0.074     -1.486      0.137      -0.254       0.035
# ar.L5         -0.1936      0.071     -2.724      0.006      -0.333      -0.054
# ar.L6         -0.1902      0.072     -2.654      0.008      -0.331      -0.050
# ar.L7         -0.1742      0.069     -2.513      0.012      -0.310      -0.038
# ar.L8         -0.0259      0.069     -0.377      0.706      -0.161       0.109
# ar.L9         -0.0792      0.068     -1.170      0.242      -0.212       0.053
# ar.L10        -0.1738      0.057     -3.046      0.002      -0.286      -0.062
# ma.L1         -1.5783      0.059    -26.821      0.000      -1.694      -1.463
# ma.L2          0.8364      0.049     17.219      0.000       0.741       0.932
# sigma2         1.2002      0.076     15.722      0.000       1.051       1.350
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                17.40
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.25   Skew:                            -0.38
# Prob(H) (two-sided):                  0.18   Kurtosis:                         3.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /home/raquel/.local/lib/python3.8/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# Modelo AR: Melhor AIC = 1339.919 (10,0,0)
#
# Modelo MA: Melhor AIC = 1411.696 (0,0,8)
#
# Modelo ARMA: Melhor AIC = 1273.766 (10,0,2)
#
# Modelo ARIMA: Melhor AIC = 1319.230 (10,1,2)

# %% [markdown]
# ### **Análise dos Resíduos**

# %%
residuos_arima = resultado_arima.resid

# %%
residuos_arima.plot()
plt.show()

# %% [markdown]
# **Normalidade**

# %%
stats.probplot(residuos_arima, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
e, p = stats.shapiro(residuos_arima)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 0.9817314743995667
# p-valor: 2.886836045945529e-05

# %%
import seaborn as sns
sns.distplot(residuos_arima);
# Out:
# /home/raquel/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Autocorrelação**

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(residuos_arima, lags=30)
plt.show()

# %%
plot_pacf(residuos_arima, lags=30)
plt.show()

# %%
plt.plot(serie3, label='Série Real')
plt.plot(serie3-residuos_arima,color='red', label='Resíduos')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Previsão**

# %%
resultado_arima.fittedvalues
# Out:
# 1985-01-31    0.000000
# 1985-02-28    5.696987
# 1985-03-31    6.027735
# 1985-04-30    6.128135
# 1985-05-31    4.814763
#                 ...
# 2020-08-31    3.530073
# 2020-09-30    3.768843
# 2020-10-31    4.547331
# 2020-11-30    5.243274
# 2020-12-31    5.616448
# Freq: M, Length: 432, dtype: float64

# %%
previsao_arima = resultado_arima.predict(start=430, end=443)
previsao_arima
# Out:
# 2020-11-30    5.243274
# 2020-12-31    5.616448
# 2021-01-31    5.498816
# 2021-02-28    5.984208
# 2021-03-31    5.577797
# 2021-04-30    4.609383
# 2021-05-31    3.662176
# 2021-06-30    3.347950
# 2021-07-31    3.550518
# 2021-08-31    3.744614
# 2021-09-30    4.269071
# 2021-10-31    4.919733
# 2021-11-30    5.678756
# 2021-12-31    6.042819
# Freq: M, Name: predicted_mean, dtype: float64

# %%
# Linha TESTE
prev_arima = pd.DataFrame(previsao_arima, columns=['Previsão_ARIMA'])
prev_arima
# Out:
# Empty DataFrame
# Columns: [Previsão_ARIMA]
# Index: []

# %%
len(prev_arima['Previsão_ARIMA'])
# Out:
# 0

# %%
prev_arima['Previsão_ARIMA'][-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/raquel/series_temporais/projeto_chuva.ipynb Célula 145 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/raquel/series_temporais/projeto_chuva.ipynb#Y264sZmlsZQ%3D%3D?line=0'>1</a> prev_arima['Previsão_ARIMA'][-1]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:955, in Series.__getitem__(self, key)
#     952     key = unpack_1tuple(key)
#     954 if is_integer(key) and self.index._should_fallback_to_positional:
# --> 955     return self._values[key]
#     957 elif key_is_scalar:
#     958     return self._get_value(key)
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
soma = np.cumsum(prev_arima['Previsão_ARIMA'][::-1])
soma
# Out:
# 2021-12-31    0.590442
# 2021-11-30    1.543922
# 2021-10-31    2.261094
# 2021-09-30    2.681989
# 2021-08-31    2.717114
# 2021-07-31    2.704416
# 2021-06-30    2.209557
# 2021-05-31    1.112163
# 2021-04-30    0.194821
# 2021-03-31   -0.002581
# 2021-02-28    0.727352
# 2021-01-31    0.072849
# 2020-12-31    0.146022
# 2020-11-30   -0.626070
# Freq: -1M, Name: Previsão_ARIMA, dtype: float64

# %%
reversao = []
for i in range(1,len(prev_arima['Previsão_ARIMA'])):
  reversao.append (prev_arima['Previsão_ARIMA'][-1]-soma[-i])
reversao.append(prev_arima['Previsão_ARIMA'][-1])
print(reversao)

# LINHA TESTE
#arima_log_diff_rev = []
#v_prev = 0
#for v in prev_arima['Previsão_ARIMA']:
    #v_prev += v
    #arima_log_diff_rev.append(v_prev)


#prev_arima['Previsão_ARIMA']=(prev_arima['Previsão_ARIMA'].cumsum())*ultimo
#prev_arima
# Out:
# [1.2165125088622193, 0.444420754155757, 0.5175932327906714, -0.13690936177452984, 0.5930235440628719, 0.3956214059132356, -0.5217205555453543, -1.6191150749218755, -2.1139739556818844, -2.1266711977507304, -2.0915468804477717, -1.6706520872039328, -0.953480147870249, 0.5904423261006768]

# %%
#df['energy']=(np.exp(df['energy'].cumsum())*last_energy)
ultimo = prev_arima['Previsão_ARIMA'].iloc[-1]
prev_arima['Previsão_ARIMA']=(prev_arima['Previsão_ARIMA'].cumsum()*ultimo)
prev_arima

# %%
previsao_arima2 = resultado_arima.forecast(24)
previsao_arima2[0]
# Out:
# array([5.52559313, 6.25552604, 6.0581239 , 5.14078194, 4.04338742,
#        3.54852854, 3.53583129, 3.57095561, 3.9918504 , 4.70902234,
#        5.66250249, 6.25294482, 6.39454539, 6.15926012, 5.67928236,
#        4.96875442, 4.19058406, 3.60639146, 3.40719593, 3.61847989,
#        4.13598943, 4.84684773, 5.59064945, 6.16532232])

# %%
prev_escala_arima = pd.DataFrame(previsao_arima2[0] ** 3, columns=['Previsão_ARIMA'])
prev_escala_arima
# Out:
#     Previsão_ARIMA
# 0       168.708401
# 1       244.788780
# 2       222.338388
# 3       135.858729
# 4        66.105267
# 5        44.683266
# 6        44.205327
# 7        45.535840
# 8        63.609616
# 9       104.422059
# 10      181.562109
# 11      244.485883
# 12      261.474308
# 13      233.660681
# 14      183.180982
# 15      122.671195
# 16       73.590825
# 17       46.904941
# 18       39.554084
# 19       47.378193
# 20       70.751925
# 21      113.861822
# 22      174.737768
# 23      234.351296

# %%
pd.concat([serie,prev_escala_arima]).plot();

# %% [markdown]
# ## **Modelo AUTO ARIMA**

# %% [markdown]
# Modelo arima:(p,d,q)
#
# Modelo SARIMA: (p,d,q)(P,D,Q)

# %% [markdown]
# Modelo AR: Melhor AIC = 1337.922 = (9,0,0)
#
# Modelo MA: Melhor AIC = 1411.696 (0,0,8)
#
# Modelo ARMA: Melhor AIC = 1273.766 (10,0,2)
#
# Modelo ARIMA: Melhor AIC = 1319.230 (10,1,2)

# %%
pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 29.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.1.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.4.4)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (0.29.33)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (67.6.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.22.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima) (1.26.15)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19->pmdarima) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.13.2->pmdarima) (23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.3

# %%
from pmdarima.arima import auto_arima

# %%
### AUTOARIMA
modelo_auto = auto_arima(serie3, trace = True, stepwise = False, seasonal=True, max_p=10, max_q=10,
                          max_P=4, max_Q=4, start_p=0, start_q=0, start_P=0, start_Q=0, m=12,)

# Trace: apresenta no console a lista dos modelos.
# stepwise: seleção gradual(processo mais rápido, porém menos minucioso).
# m: período sazonal (neste caso mensal).
# Interessante dobrar as ordens máximas: max.p = 10, max.q = 10, max.P = 4, max.Q = 4
# Out:
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=1618.370, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=1503.636, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=1474.263, Time=0.76 sec
#  ARIMA(0,0,0)(0,0,3)[12] intercept   : AIC=1437.044, Time=2.12 sec
#  ARIMA(0,0,0)(0,0,4)[12] intercept   : AIC=1419.293, Time=4.18 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=1427.651, Time=0.51 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.35 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=4.63 sec
#  ARIMA(0,0,0)(1,0,3)[12] intercept   : AIC=1270.589, Time=10.09 sec
#  ARIMA(0,0,0)(1,0,4)[12] intercept   : AIC=inf, Time=20.42 sec
#  ARIMA(0,0,0)(2,0,0)[12] intercept   : AIC=1385.579, Time=2.02 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=3.46 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=5.43 sec
#  ARIMA(0,0,0)(2,0,3)[12] intercept   : AIC=inf, Time=11.87 sec
#  ARIMA(0,0,0)(3,0,0)[12] intercept   : AIC=inf, Time=6.27 sec
#  ARIMA(0,0,0)(3,0,1)[12] intercept   : AIC=2046.915, Time=3.42 sec
#  ARIMA(0,0,0)(3,0,2)[12] intercept   : AIC=inf, Time=10.94 sec
#  ARIMA(0,0,0)(4,0,0)[12] intercept   : AIC=inf, Time=16.79 sec
# /usr/local/lib/python3.7/dist-packages/pmdarima/arima/_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(0,0,0)(4,0,1)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pmdarima/arima/_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "/usr/local/lib/python3.7/dist-packages/pmdarima/arima/arima.py", line 597, in fit
#     self._fit(y, X, **fit_args)
#   File "/usr/local/lib/python3.7/dist-packages/pmdarima/arima/arima.py", line 518, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "/usr/local/lib/python3.7/dist-packages/pmdarima/arima/arima.py", line 512, in _fit_wrapper
#     **fit_args)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/mlemodel.py", line 709, in fit
#     skip_hessian=True, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py", line 571, in fit
#     full_output=full_output)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/base/optimizer.py", line 244, in _fit
#     hess=hessian)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/base/optimizer.py", line 654, in _fit_lbfgs
#     **extra_kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py", line 199, in fmin_l_bfgs_b
#     **opts)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py", line 345, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py", line 290, in func_and_grad
#     f = fun(x, *args)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py", line 327, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py", line 531, in f
#     return -self.loglike(params, *args) / nobs
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/mlemodel.py", line 939, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/representation.py", line 984, in _initialize_state
#     complex_step=complex_step)
#   File "statsmodels/tsa/statespace/_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels/tsa/statespace/_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
#  ARIMA(0,0,0)(4,0,1)[12] intercept   : AIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=1534.551, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=1464.951, Time=0.39 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=1448.732, Time=1.00 sec
#  ARIMA(0,0,1)(0,0,3)[12] intercept   : AIC=1418.891, Time=2.56 sec
#  ARIMA(0,0,1)(0,0,4)[12] intercept   : AIC=1406.458, Time=5.24 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=1419.367, Time=0.80 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.84 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=5.33 sec
#  ARIMA(0,0,1)(1,0,3)[12] intercept   : AIC=1279.037, Time=11.16 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=1383.694, Time=2.51 sec
#  ARIMA(0,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=4.08 sec
#  ARIMA(0,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=5.84 sec
#  ARIMA(0,0,1)(3,0,0)[12] intercept   : AIC=1340.191, Time=7.42 sec
#  ARIMA(0,0,1)(3,0,1)[12] intercept   : AIC=inf, Time=12.05 sec
#  ARIMA(0,0,1)(4,0,0)[12] intercept   : AIC=1325.565, Time=17.07 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=1490.597, Time=0.19 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : AIC=1437.867, Time=0.49 sec
#  ARIMA(0,0,2)(0,0,2)[12] intercept   : AIC=1426.796, Time=1.35 sec
#  ARIMA(0,0,2)(0,0,3)[12] intercept   : AIC=1402.592, Time=3.45 sec
#  ARIMA(0,0,2)(1,0,0)[12] intercept   : AIC=1408.127, Time=0.86 sec
#  ARIMA(0,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=2.43 sec
#  ARIMA(0,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=6.55 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=1380.031, Time=2.83 sec
#  ARIMA(0,0,2)(2,0,1)[12] intercept   : AIC=inf, Time=5.63 sec
#  ARIMA(0,0,2)(3,0,0)[12] intercept   : AIC=1340.062, Time=8.11 sec
#  ARIMA(0,0,3)(0,0,0)[12] intercept   : AIC=1486.899, Time=0.18 sec
#  ARIMA(0,0,3)(0,0,1)[12] intercept   : AIC=1438.927, Time=0.51 sec
#  ARIMA(0,0,3)(0,0,2)[12] intercept   : AIC=1428.734, Time=1.48 sec
#  ARIMA(0,0,3)(1,0,0)[12] intercept   : AIC=1409.402, Time=0.98 sec
#  ARIMA(0,0,3)(1,0,1)[12] intercept   : AIC=inf, Time=2.99 sec
#  ARIMA(0,0,3)(2,0,0)[12] intercept   : AIC=1377.837, Time=2.97 sec
#  ARIMA(0,0,4)(0,0,0)[12] intercept   : AIC=1484.168, Time=0.26 sec
#  ARIMA(0,0,4)(0,0,1)[12] intercept   : AIC=1440.927, Time=0.85 sec
#  ARIMA(0,0,4)(1,0,0)[12] intercept   : AIC=1408.931, Time=1.22 sec
#  ARIMA(0,0,5)(0,0,0)[12] intercept   : AIC=1473.158, Time=0.39 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=1498.443, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=1448.643, Time=0.41 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=1437.723, Time=1.18 sec
#  ARIMA(1,0,0)(0,0,3)[12] intercept   : AIC=1411.823, Time=2.77 sec
#  ARIMA(1,0,0)(0,0,4)[12] intercept   : AIC=1401.828, Time=5.65 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=1415.817, Time=0.85 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.83 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=4.84 sec
#  ARIMA(1,0,0)(1,0,3)[12] intercept   : AIC=1270.666, Time=10.73 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=1382.882, Time=2.44 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=5.97 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=1289.479, Time=5.28 sec
#  ARIMA(1,0,0)(3,0,0)[12] intercept   : AIC=inf, Time=8.07 sec
#  ARIMA(1,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=12.41 sec
#  ARIMA(1,0,0)(4,0,0)[12] intercept   : AIC=inf, Time=17.68 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=1500.067, Time=0.25 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=1449.083, Time=0.54 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=1437.859, Time=2.32 sec
#  ARIMA(1,0,1)(0,0,3)[12] intercept   : AIC=1412.158, Time=4.31 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=1416.288, Time=1.69 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.95 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=5.81 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=1385.056, Time=4.63 sec
# /usr/local/lib/python3.7/dist-packages/pmdarima/arima/_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(1,0,1)(2,0,1)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pmdarima/arima/_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "/usr/local/lib/python3.7/dist-packages/pmdarima/arima/arima.py", line 597, in fit
#     self._fit(y, X, **fit_args)
#   File "/usr/local/lib/python3.7/dist-packages/pmdarima/arima/arima.py", line 518, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "/usr/local/lib/python3.7/dist-packages/pmdarima/arima/arima.py", line 512, in _fit_wrapper
#     **fit_args)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/mlemodel.py", line 709, in fit
#     skip_hessian=True, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py", line 571, in fit
#     full_output=full_output)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/base/optimizer.py", line 244, in _fit
#     hess=hessian)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/base/optimizer.py", line 654, in _fit_lbfgs
#     **extra_kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py", line 199, in fmin_l_bfgs_b
#     **opts)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py", line 345, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py", line 290, in func_and_grad
#     f = fun(x, *args)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py", line 327, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py", line 531, in f
#     return -self.loglike(params, *args) / nobs
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/mlemodel.py", line 939, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/kalman_filter.py", line 983, in loglike
#     kfilter = self._filter(**kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/kalman_filter.py", line 903, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/representation.py", line 984, in _initialize_state
#     complex_step=complex_step)
#   File "statsmodels/tsa/statespace/_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels/tsa/statespace/_tools.pyx", line 1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=nan sec
#  ARIMA(1,0,1)(3,0,0)[12] intercept   : AIC=1344.840, Time=7.97 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=1486.602, Time=0.31 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=1439.061, Time=0.80 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=1428.745, Time=2.57 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=1409.704, Time=1.98 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=3.00 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=1380.113, Time=5.37 sec
#  ARIMA(1,0,3)(0,0,0)[12] intercept   : AIC=1487.763, Time=0.46 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=1440.927, Time=1.68 sec
#  ARIMA(1,0,3)(1,0,0)[12] intercept   : AIC=1409.345, Time=2.05 sec
#  ARIMA(1,0,4)(0,0,0)[12] intercept   : AIC=1452.326, Time=1.34 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=1499.659, Time=0.17 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=1447.261, Time=0.46 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=1435.523, Time=1.37 sec
#  ARIMA(2,0,0)(0,0,3)[12] intercept   : AIC=1409.927, Time=3.80 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=1413.979, Time=1.70 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=2.12 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=5.40 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=1382.746, Time=3.10 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=6.58 sec
#  ARIMA(2,0,0)(3,0,0)[12] intercept   : AIC=inf, Time=8.36 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=1498.246, Time=0.63 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=inf, Time=1.95 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=1441.657, Time=3.01 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=1418.996, Time=1.49 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=2.51 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=1384.476, Time=4.89 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=inf, Time=3.19 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=1411.064, Time=2.66 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=1339.972, Time=1.59 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=1471.799, Time=0.22 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=1432.394, Time=0.79 sec
#  ARIMA(3,0,0)(0,0,2)[12] intercept   : AIC=1423.727, Time=1.98 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=1407.152, Time=1.44 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=3.06 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=1377.774, Time=4.10 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=1382.559, Time=1.09 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=1371.164, Time=1.89 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=1388.786, Time=3.28 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=1492.158, Time=1.23 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=1444.637, Time=0.29 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=1417.966, Time=0.79 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=1403.292, Time=1.64 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=1369.812, Time=1.58 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=1400.807, Time=0.54 sec
#
# Best model:  ARIMA(0,0,0)(1,0,3)[12] intercept
# Total fit time: 455.589 seconds

# %%
print(modelo_auto.aic())

# %% [markdown]
# Modelo AR: Melhor AIC = 1339.919 (10,0,0)
#
# Modelo MA: Melhor AIC = 1411.696 (0,0,8)
#
# Modelo ARMA: Melhor AIC = 1273.766 (10,0,2)
#
# Modelo ARIMA: Melhor AIC = 1319.230 (10,1,2)
#
# Modelo_AUTOARIMA: AIC=1270.5894 ARIMA(0,0,0)(1,0,3)

# %%
resultado_auto = modelo_auto.fit(serie3)
print(resultado_auto.summary())

# %% [markdown]
# ### **Análise dos Resíduos**

# %%
residuos_auto = resultado_auto.resid
residuos_auto()

# %%
plt.plot(residuos_auto())
plt.show()

# %% [markdown]
# **Normalidade**

# %%
stats.probplot(residuos_auto(), dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
e, p = stats.shapiro(residuos_auto())
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))

# %%
import seaborn as sns
sns.distplot(residuos_auto());

# %% [markdown]
# **Autocorrelação**

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(residuos_auto(), lags=30)
plt.show()

# %%
plot_pacf(residuos_auto(), lags=30)
plt.show()

# %%
plt.plot(serie3, label='Série Real')
plt.plot(serie3-residuos_auto(),color='red', label='Resíduos')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Previsão**

# %%
previsao_auto = resultado_auto.predict(n_periods=48)
previsao_auto

# %%
prev_escala_auto = pd.DataFrame(previsao_auto ** 3, columns=['Previsão_SARIMA'])
prev_escala_auto

# %%
pd.concat([serie,prev_escala_auto]).plot();

# %% [markdown]
# ## **Análise final do projeto**

# %% [markdown]
# **COMPARAÇÃO DOS MODELOS**

# %% [markdown]
# Modelo AR: Melhor AIC = 1339.919 (10,0,0)
#
# Modelo MA: Melhor AIC = 1411.696 (0,0,8)
#
# Modelo ARMA: Melhor AIC = 1273.766 (10,0,2)
#
# Modelo ARIMA: Melhor AIC = 1319.230 (10,1,2)
#
# **Modelo_SARIMA (AutoArima): AIC=1270.5894 ARIMA(0,0,0)(1,0,3)**

# %% [markdown]
# **DESEMPENHO DOS MODELOS**

# %%
# Lista com valores reais de 2021
lista = [373.3, 174.1, 137.8, 55.7]
valores_reais = pd.DataFrame(lista, columns = ['valores reais'])
print(valores_reais)

# %%
auto = prev_escala_auto.iloc[0:4]
auto

# %%
desempenho = pd.concat([valores_reais, auto],axis=1)
desempenho

# %%
ar = prev_escala.iloc[1:5]
ar

# %%
pd.DataFrame.reset_index(ar, drop=True, inplace=True)
ar

# %%
ma = prev_escala_ma.iloc[1:5]
ma

# %%
pd.DataFrame.reset_index(ma, drop=True, inplace=True)
ma

# %%
arma = prev_escala_arma.iloc[1:5]
arma

# %%
pd.DataFrame.reset_index(arma, drop=True, inplace=True)
arma

# %%
arima = prev_escala_arima.iloc[0:4]
arima

# %%
desempenho = pd.concat([desempenho, ar, ma, arma, arima],axis=1)
desempenho

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# **ERRO MÉDIO ABSOLUTO (MAE)**

# %%
print('ERRO MÉDIO ABSOLUTO (MAE)')
mae_sarima = mean_absolute_error(desempenho['valores reais'], desempenho['Previsão_SARIMA'])
print('SARIMA: {:.2f}'.format(mae_sarima))
mae_ar = mean_absolute_error(desempenho['valores reais'], desempenho['Previsão_AR'])
print('AR: {:.2f}'.format(mae_ar))
mae_ma = mean_absolute_error(desempenho['valores reais'], desempenho['Previsão_MA'])
print('MA: {:.2f}'.format(mae_ma))
mae_arma = mean_absolute_error(desempenho['valores reais'], desempenho['Previsão_ARMA'])
print('ARMA: {:.2f}'.format(mae_arma))
mae_arima = mean_absolute_error(desempenho['valores reais'], desempenho['Previsão_ARIMA'])
print('ARIMA: {:.2f}'.format(mae_arima))

# %% [markdown]
# **ERRO QUADRÁTICO MÉDIO (MSE)**

# %%
print('ERRO QUADRÁTICO MÉDIO (MSE)')
mse_sarima = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_SARIMA'])
print('SARIMA: {:.2f}'.format(mse_sarima))
mse_ar = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_AR'])
print('AR: {:.2f}'.format(mse_ar))
mse_ma = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_MA'])
print('MA: {:.2f}'.format(mse_ma))
mse_arma = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_ARMA'])
print('ARMA: {:.2f}'.format(mse_arma))
mse_arima = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_ARIMA'])
print('ARIMA: {:.2f}'.format(mse_arima))

# %% [markdown]
# **RAIZ DO ERRO QUADRÁTICO MÉDIO (RMSE)**

# %%
print('RAIZ DO ERRO QUADRÁTICO MÉDIO (RMSE)')
rmse_sarima = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_SARIMA'], squared=False)
print('SARIMA: {:.2f}'.format(rmse_sarima))
rmse_ar = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_AR'], squared=False)
print('AR: {:.2f}'.format(rmse_ar))
rmse_ma = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_MA'], squared=False)
print('MA: {:.2f}'.format(rmse_ma))
rmse_arma = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_ARMA'], squared=False)
print('ARMA: {:.2f}'.format(rmse_arma))
rmse_arima = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_ARIMA'], squared=False)
print('ARIMA: {:.2f}'.format(rmse_arima))

# %% [markdown]
# **Sugestões de Estudos:**
#
# 1) Criar uma série com a data final até dezembro de 2019.
#
# 2) Fazer todo o estudo com o dataset elnino do Python.

# %% [markdown]
# https://www.statsmodels.org/devel/datasets/index.html

# %%
import statsmodels.api as sm
sm.datasets.elnino.load_pandas().data
