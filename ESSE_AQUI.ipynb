# %% [markdown]
# # Projeto de Séries Temporais
# ## Chuvas no município de São Paulo
# ### João Honorato, Maria Raquel
#
# Estamos usando dados mensais de precipitação de chuva no município de São Paulo, extraídos do Departamento de Águas e Energia Elétrica (DAEE), do período de 1985 a 2022
#
# link: http://www.hidrologia.daee.sp.gov.br/
#
# A chuva é medida em milímetros, 1 mm de altura de chuva equivale ao volume de 1 litro precipitado sobre uma superfície de 1 m² de área.
#
# As alturas mensais de chuva são as acumuladas entre 7 horas do último dia do mês anterior até às 7 horas do último dia do mês considerado.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Carregando e tratando os dados

# %%
# Carregando os dados

chuvasp = pd.read_csv('E3-262_Chuva_Mensal_Serie_20230830_084446.csv', sep=';')
chuvasp.head()
# Out:
#       Ano Janeiro Fevereiro   Março   Abril    Maio   Junho   Julho Agosto  \
# 0    1985  184,90    242,90  230,00   59,00  126,20   14,60    4,00  21,80
# 1    1986  199,60    221,00  218,70  106,50  113,10    3,90   30,30    ---
# 2    1987  525,80       ---  161,30   98,10  293,80  183,90   11,80  30,90
# 3    1988  268,70    224,40  189,20  175,10  224,90   58,60    1,30   0,20
# 4    1989  312,90    344,30  288,20   66,30   21,70   52,50  150,10  32,90
#
#   Setembro Outubro Novembro Dezembro
# 0   126,10   71,10   111,30   155,20
# 1    34,50   60,70   242,50   389,90
# 2    80,20   84,80    72,70   152,10
# 3    28,40  173,90   100,20   289,80
# 4    52,10   80,10    88,00   236,70

# %%
# Precisamos substituir as vírgulas por pontos para converter os valores para float

chuvasp = chuvasp.replace(',','.', regex=True)
chuvasp.head()
# Out:
#       Ano Janeiro Fevereiro   Março   Abril    Maio   Junho   Julho Agosto  \
# 0    1985  184.90    242.90  230.00   59.00  126.20   14.60    4.00  21.80
# 1    1986  199.60    221.00  218.70  106.50  113.10    3.90   30.30    ---
# 2    1987  525.80       ---  161.30   98.10  293.80  183.90   11.80  30.90
# 3    1988  268.70    224.40  189.20  175.10  224.90   58.60    1.30   0.20
# 4    1989  312.90    344.30  288.20   66.30   21.70   52.50  150.10  32.90
#
#   Setembro Outubro Novembro Dezembro
# 0   126.10   71.10   111.30   155.20
# 1    34.50   60.70   242.50   389.90
# 2    80.20   84.80    72.70   152.10
# 3    28.40  173.90   100.20   289.80
# 4    52.10   80.10    88.00   236.70

# %%
# De acordo com o DAEE, valores com '---' representam dados inexistentes.
# Vamos substituí-los pela de chuvas de cada mês, dado presente na última linha do dataset

chuvasp.tail()
# Out:
#          Ano Janeiro Fevereiro   Março   Abril   Maio   Junho   Julho Agosto  \
# 34      2019     ---    315.50  318.50  172.30  97.30   59.00  195.10   6.70
# 35      2020  408.10    363.00   95.50    5.60  13.70  163.80   10.20  62.10
# 36      2021  373.30    174.10  137.80   55.70  38.50   15.50   38.00  44.80
# 37      2022  418.40    136.30  233.60   40.40  67.30   45.90    8.80  35.20
# 38    Média:  309.01    249.32  228.13   92.24  84.89   58.09   51.79  28.56
#
#    Setembro Outubro Novembro Dezembro
# 34    73.70   75.90   170.80   249.00
# 35    22.90  213.90   162.10      ---
# 36      ---  152.80   108.20   247.40
# 37   131.30  117.30   197.70   200.40
# 38    85.08  139.63   145.48   235.36

# %%
for coluna, i in zip(chuvasp.columns, range(14)):
    chuvasp[coluna] = chuvasp[coluna].str.replace('---', f'{chuvasp.iloc[-1][i]}')

chuvasp.tail()
# Out:
#          Ano Janeiro Fevereiro   Março   Abril   Maio   Junho   Julho Agosto  \
# 34      2019  309.01    315.50  318.50  172.30  97.30   59.00  195.10   6.70
# 35      2020  408.10    363.00   95.50    5.60  13.70  163.80   10.20  62.10
# 36      2021  373.30    174.10  137.80   55.70  38.50   15.50   38.00  44.80
# 37      2022  418.40    136.30  233.60   40.40  67.30   45.90    8.80  35.20
# 38    Média:  309.01    249.32  228.13   92.24  84.89   58.09   51.79  28.56
#
#    Setembro Outubro Novembro Dezembro
# 34    73.70   75.90   170.80   249.00
# 35    22.90  213.90   162.10   235.36
# 36    85.08  152.80   108.20   247.40
# 37   131.30  117.30   197.70   200.40
# 38    85.08  139.63   145.48   235.36

# %%
valores_medios = chuvasp.iloc[-1][1:].values.astype(float)
valores_medios
# Out:
# array([309.01, 249.32, 228.13,  92.24,  84.89,  58.09,  51.79,  28.56,
#         85.08, 139.63, 145.48, 235.36])

# %%
# Excluiremos a última linha
chuvasp = chuvasp.drop(chuvasp[chuvasp['Ano'] == '  Média:'].index)

chuvasp.tail()
# Out:
#        Ano Janeiro Fevereiro   Março   Abril   Maio   Junho   Julho Agosto  \
# 33    2018  238.20     84.50  228.13   66.40  25.80   15.00   20.50  28.56
# 34    2019  309.01    315.50  318.50  172.30  97.30   59.00  195.10   6.70
# 35    2020  408.10    363.00   95.50    5.60  13.70  163.80   10.20  62.10
# 36    2021  373.30    174.10  137.80   55.70  38.50   15.50   38.00  44.80
# 37    2022  418.40    136.30  233.60   40.40  67.30   45.90    8.80  35.20
#
#    Setembro Outubro Novembro Dezembro
# 33    72.90  203.40   134.10   258.00
# 34    73.70   75.90   170.80   249.00
# 35    22.90  213.90   162.10   235.36
# 36    85.08  152.80   108.20   247.40
# 37   131.30  117.30   197.70   200.40

# %%
# Excluiremos a coluna ano
chuvasp = chuvasp.drop(columns=['Ano'])

chuvasp.tail()
# Out:
#    Janeiro Fevereiro   Março   Abril   Maio   Junho   Julho Agosto Setembro  \
# 33  238.20     84.50  228.13   66.40  25.80   15.00   20.50  28.56    72.90
# 34  309.01    315.50  318.50  172.30  97.30   59.00  195.10   6.70    73.70
# 35  408.10    363.00   95.50    5.60  13.70  163.80   10.20  62.10    22.90
# 36  373.30    174.10  137.80   55.70  38.50   15.50   38.00  44.80    85.08
# 37  418.40    136.30  233.60   40.40  67.30   45.90    8.80  35.20   131.30
#
#    Outubro Novembro Dezembro
# 33  203.40   134.10   258.00
# 34   75.90   170.80   249.00
# 35  213.90   162.10   235.36
# 36  152.80   108.20   247.40
# 37  117.30   197.70   200.40

# %%
# Convertendo os valores para float

chuvasp = chuvasp.astype(float)

# %%
valores = list(chuvasp.values.flatten())
print(valores)
# Out:
# [184.9, 242.9, 230.0, 59.0, 126.2, 14.6, 4.0, 21.8, 126.1, 71.1, 111.3, 155.2, 199.6, 221.0, 218.7, 106.5, 113.1, 3.9, 30.3, 28.56, 34.5, 60.7, 242.5, 389.9, 525.8, 249.32, 161.3, 98.1, 293.8, 183.9, 11.8, 30.9, 80.2, 84.8, 72.7, 152.1, 268.7, 224.4, 189.2, 175.1, 224.9, 58.6, 1.3, 0.2, 28.4, 173.9, 100.2, 289.8, 312.9, 344.3, 288.2, 66.3, 21.7, 52.5, 150.1, 32.9, 52.1, 80.1, 88.0, 236.7, 284.1, 196.9, 310.1, 85.8, 77.9, 50.6, 121.2, 76.3, 97.2, 206.8, 116.3, 149.8, 330.7, 340.3, 522.4, 200.3, 43.3, 96.8, 28.2, 37.3, 101.4, 168.0, 67.3, 237.9, 129.2, 258.5, 228.13, 87.2, 93.5, 11.6, 40.9, 24.7, 150.6, 219.6, 145.48, 211.7, 221.5, 225.7, 110.0, 84.6, 133.9, 74.7, 11.2, 40.8, 210.1, 134.1, 125.5, 170.5, 196.9, 184.4, 231.6, 111.4, 54.9, 30.5, 39.2, 2.4, 1.8, 147.6, 86.6, 276.3, 373.8, 383.1, 267.7, 73.9, 79.7, 31.2, 46.8, 1.5, 44.2, 202.6, 115.1, 235.36, 334.3, 376.5, 284.5, 42.3, 21.7, 45.1, 12.2, 41.2, 179.4, 179.8, 87.4, 243.9, 235.0, 187.6, 57.1, 63.2, 88.2, 124.7, 12.5, 28.8, 118.0, 151.8, 236.3, 217.4, 231.6, 430.1, 211.2, 56.9, 133.8, 16.6, 16.6, 45.5, 99.5, 203.1, 41.5, 198.4, 309.01, 339.0, 162.3, 34.9, 47.2, 86.3, 31.0, 0.0, 76.9, 64.5, 76.0, 100.4, 387.7, 304.0, 190.4, 50.0, 9.7, 9.8, 74.0, 28.56, 120.3, 105.5, 322.0, 281.0, 283.1, 221.9, 241.2, 28.7, 85.0, 31.0, 31.7, 26.9, 82.3, 213.1, 181.6, 292.9, 300.6, 173.6, 354.8, 95.3, 137.6, 2.3, 23.0, 41.5, 84.0, 143.9, 201.4, 263.7, 443.4, 141.5, 250.2, 45.5, 36.6, 20.7, 24.5, 27.6, 41.5, 176.7, 133.0, 89.9, 188.8, 316.9, 127.2, 160.5, 77.4, 75.6, 105.6, 2.2, 13.8, 120.6, 215.5, 181.0, 378.3, 95.9, 202.1, 137.3, 177.1, 35.1, 39.8, 11.5, 150.3, 195.3, 96.6, 140.1, 230.9, 223.5, 407.9, 65.4, 23.7, 34.8, 78.6, 9.2, 86.2, 71.9, 175.0, 353.3, 208.7, 301.0, 240.2, 67.6, 63.1, 17.2, 134.3, 0.1, 27.4, 167.2, 211.7, 268.7, 388.0, 136.4, 332.8, 123.6, 80.9, 55.7, 0.0, 52.5, 49.9, 144.3, 125.4, 152.9, 356.4, 145.0, 73.6, 75.3, 58.1, 28.3, 157.7, 28.56, 198.9, 157.4, 237.2, 294.5, 549.1, 175.4, 258.9, 116.4, 52.8, 20.2, 78.4, 1.2, 100.4, 73.8, 129.2, 234.7, 428.4, 349.5, 265.1, 142.0, 40.1, 81.3, 1.5, 49.7, 10.7, 218.2, 73.4, 393.7, 401.5, 226.0, 165.9, 149.1, 82.4, 58.09, 105.5, 3.7, 31.9, 93.9, 154.0, 623.2, 321.7, 372.1, 175.0, 103.4, 39.4, 210.9, 168.8, 15.3, 45.1, 110.7, 76.6, 139.9, 189.7, 236.1, 222.9, 110.2, 71.0, 11.5, 51.9, 20.5, 82.1, 23.8, 209.3, 258.0, 249.3, 303.5, 265.9, 100.4, 87.2, 25.4, 62.7, 40.5, 280.9, 139.63, 145.48, 221.9, 242.8, 225.2, 288.1, 92.2, 141.4, 207.3, 0.0, 82.2, 29.1, 116.9, 181.2, 129.2, 309.01, 249.32, 120.8, 156.3, 166.1, 101.6, 0.2, 53.4, 12.0, 121.2, 174.4, 169.6, 238.2, 84.5, 228.13, 66.4, 25.8, 15.0, 20.5, 28.56, 72.9, 203.4, 134.1, 258.0, 309.01, 315.5, 318.5, 172.3, 97.3, 59.0, 195.1, 6.7, 73.7, 75.9, 170.8, 249.0, 408.1, 363.0, 95.5, 5.6, 13.7, 163.8, 10.2, 62.1, 22.9, 213.9, 162.1, 235.36, 373.3, 174.1, 137.8, 55.7, 38.5, 15.5, 38.0, 44.8, 85.08, 152.8, 108.2, 247.4, 418.4, 136.3, 233.6, 40.4, 67.3, 45.9, 8.8, 35.2, 131.3, 117.3, 197.7, 200.4]

# %%
anos = pd.date_range('1985', periods = len(valores), freq = 'M')
anos
# Out:
# DatetimeIndex(['1985-01-31', '1985-02-28', '1985-03-31', '1985-04-30',
#                '1985-05-31', '1985-06-30', '1985-07-31', '1985-08-31',
#                '1985-09-30', '1985-10-31',
#                ...
#                '2022-03-31', '2022-04-30', '2022-05-31', '2022-06-30',
#                '2022-07-31', '2022-08-31', '2022-09-30', '2022-10-31',
#                '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=456, freq='M')

# %%
serie = pd.Series(valores, index = anos)
serie
# Out:
# 1985-01-31    184.9
# 1985-02-28    242.9
# 1985-03-31    230.0
# 1985-04-30     59.0
# 1985-05-31    126.2
#               ...
# 2022-08-31     35.2
# 2022-09-30    131.3
# 2022-10-31    117.3
# 2022-11-30    197.7
# 2022-12-31    200.4
# Freq: M, Length: 456, dtype: float64

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov','Dez']
serie_medias = pd.Series(valores_medios, index = meses)
serie_medias
# Out:
# Jan    309.01
# Fev    249.32
# Mar    228.13
# Abr     92.24
# Mai     84.89
# Jun     58.09
# Jul     51.79
# Ago     28.56
# Set     85.08
# Out    139.63
# Nov    145.48
# Dez    235.36
# dtype: float64

# %% [markdown]
# ### Gráficos da série temporal

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=serie.index, y=serie.values,
                    mode='lines',
                    name='lines'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 10)
serie_medias.plot();

# %% [markdown]
# ### Média móvel

# %% [markdown]
# A média móvel é utilizada para suavizar grandes desvios e auxiliar a identificação de tendências nos dados. Usaremos a média móvel dos últimos seis meses no presente trabalho.

# %%
media_movel = serie.rolling(window = 6)
media_movel = media_movel.mean()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=media_movel.index, y=media_movel.values,
                    mode='lines',
                    name='lines'))
fig.update_layout(title='Média móvel de 6 meses das chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=serie.index, y=serie.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=media_movel.index, y=media_movel.values,
                    mode='lines',
                    name='Média móvel'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %% [markdown]
# ### Decomposição

# %% [markdown]
# Vamos decompor a série em tendência, sazonalidade e resíduos:

# %%
plt.rcParams['figure.figsize'] = (20, 10)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposicao = seasonal_decompose(serie)
decomposicao.plot();

# %% [markdown]
# Observações:
#
# - Tendência apresenta muitas oscilações, não demonstrando comportamento crescente ou decrescente
# - Além disso, a tendência não possui ciclos bem definidos, dado o seu comportamento oscilatório
# - Forte sazonalidade, com picos constantes e intervalos bem definidos (aproximadamente um ano)
# - Resíduos serão utilizados para construção e validação dos modelos

# %% [markdown]
# ### Normalidade

# %%
import scipy.stats as stats
stats.probplot(serie, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %% [markdown]
# Graficamente, notamos que os dados não seguem uma distribuição normal. Mesmo assim, faremos um teste de hipóteses para verificação da normalidade da série. Usaremos o teste de Shapiro-Wilk, ideal para o tamanho da amostra, com nível de significância de 5%.

# %% [markdown]
# **Teste Shapiro-Wilk**
#
#
# - H0 = distribuição normal p > 0,05
# - H1 = distribuição não normal p <= 0,05

# %%
e, p = stats.shapiro(serie)
print(f'Estátistica de teste: {e:.4f}')
print(f'p-valor: {p:.4e}')
# Out:
# Estátistica de teste: 0.9243
# p-valor: 2.1459e-14

# %% [markdown]
# De fato, os dados não seguem uma distribuição normal.
#
# Para fazer com que a série se aproxime de uma distribuição normal, faremos uma transformação por raiz cúbica. Assim, criaremos uma nova série, composta pela raiz cúbica dos dados originais.

# %%
serie_n = (serie)**(1/3)
stats.probplot(serie_n, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %% [markdown]
# Após a transformação, os dados já estão mais próximos de uma distribuição normal. Para comprovar isso, repetiremos o teste de Shapiro-Wilk.

# %%
e, p = stats.shapiro(serie_n)
print(f'Estátistica de teste: {e:.4f}')
print(f'p-valor: {p:.4e}')
# Out:
# Estátistica de teste: 0.9843
# p-valor: 7.8649e-05

# %% [markdown]
# Ainda não obtivemos uma distribuição normal, mas estamos mais próximos do que a série original.

# %%
import seaborn as sns

sns.distplot(serie);
# Out:
# C:\Users\jahon\AppData\Local\Temp\ipykernel_3164\103337203.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
sns.distplot(serie_n);
# Out:
# C:\Users\jahon\AppData\Local\Temp\ipykernel_3164\4180245685.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# ### Estacionariedade

# %% [markdown]
# Estacionariedade é a característica de séries que se desenvolvem no tempo através de uma média/variância constante.
#
# Séries não estacionárias costumam seguir uma tendência e mudam de comportamento por inclinação ou mudança de nível no gráfico.
#
# Para determinar a estacionariedade de uma série, utilizamos testes estatísticos. Para a nossa série, usaremos o teste KPSS.

# %% [markdown]
# **Teste KPSS (Kwiatkowski-Phillips-Schmidt-Shin)**
#
# - H0 = não é estacionário: estatística do teste > valor crítico
# - H1 = é estacionário:  estatística do teste < valor crítico
#
# Para escolha do valor crítico, utilizaremos o valor de referência para 5%

# %%
import statsmodels.tsa.stattools

kpss = statsmodels.tsa.stattools.kpss(serie_n)
print('Estatítica do teste: {:.4f}'.format(kpss[0]))
print('p_valor: {:.4f}'.format(kpss[1]))
print('Valores Críticos:')
for chave, valor in kpss[3].items():
    print('{}: {:.4f}'.format(chave, valor))
# Out:
# Estatítica do teste: 0.0166
# p_valor: 0.1000
# Valores Críticos:
# 10%: 0.3470
# 5%: 0.4630
# 2.5%: 0.5740
# 1%: 0.7390
# C:\Users\jahon\AppData\Local\Temp\ipykernel_3164\2338894414.py:3: InterpolationWarning:
#
# The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.

# %% [markdown]
# Como a estatística de teste deu um valor inferior ao valor crítico para 5%, temos que a série **É ESTACIONÁRIA**
#
# Dessa forma, não será necessário fazer a diferenciação.

# %% [markdown]
# ### Autocorrelação

# %% [markdown]
# A autocorrelação ocorre quando há **correlação entre determinados períodos anteriores com o período atual.**
#
# Períodos com autocorrelação são chamados de lags.
#
# A análise de autocorrelação dos resíduos é um **pressuposto para construção e validação de modelos preditivos.**
#
#
# Para verificar a autocorrelação, utilizaremos os **diagramas ACF e PACF.**

# %% [markdown]
# Veremos nos diagramas abaixo que série **é autocorrelacionada**, com valores acima do intervalo de confiança.
#
# Isso não será um problema, pois esse é um pressuposto da análise dos resíduos dos modelos de séries temporais.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(serie_n, lags=20)
plt.show()

# %%
plot_pacf(serie, lags=20)
plt.show()

# %% [markdown]
# Modelos ARIMA não sazonais são geralmente denotados como ARIMA( p , d , q), em que os parâmetros p, d e q são números inteiros não negativos, p é a ordem (número de defasagens) do modelo auto-regressivo, d é o grau de diferenciação (o número de vezes em que os dados tiveram valores passados subtraídos) e q é a ordem do modelo de média móvel. Modelos ARIMA sazonais são geralmente denotados como ARIMA( p , d , q )( P , D , Q) m, em que m se refere ao número de períodos em cada temporada e P, D e Q se referem aos termos de auto-regressão, diferenciação e média móvel para a parte sazonal do modelo ARIMA.

# %% [markdown]
# ## **Modelo AR**
#
# Modelos ARIMA não sazonais são geralmente denotados como ARIMA(p, d, q), em que o parâmetro p é a ordem do modelo auto-regressivo, d é o grau de diferenciação e q é a ordem do modelo de média móvel.
#
#
# O modelo AR (Auto-Regressivo) indica que a variável evoluinte de interesse é regressada em seus próprios valores anteriores.
#
# Ele é um modelo ARIMA nos quais os parâmetros d e q são nulos e o parâmetro p não.

# %% [markdown]
# AIC (Critério de Informação de Akaike) e BIC (Critério de Informação Bayesiano) são métricas que mensuram a qualidade de um modelo estatístico. Quanto menor for o AIC e BIC, melhor é o modelo.

# %%
from statsmodels.tsa.arima.model import ARIMA

for p in range(1, 11):
    modelo_ar = ARIMA(serie_n, order = (p,0,0))
    teste = modelo_ar.fit()
    print(f'ARIMA({p},0,0) - AIC: {teste.aic:.4f}')
# Out:
# ARIMA(1,0,0) - AIC: 1577.9084
# ARIMA(2,0,0) - AIC: 1578.8461
# ARIMA(3,0,0) - AIC: 1548.7956
# ARIMA(4,0,0) - AIC: 1515.7202
# ARIMA(5,0,0) - AIC: 1468.4165
# ARIMA(6,0,0) - AIC: 1422.5240
# ARIMA(7,0,0) - AIC: 1397.3217
# ARIMA(8,0,0) - AIC: 1398.1132
# ARIMA(9,0,0) - AIC: 1400.0770
# ARIMA(10,0,0) - AIC: 1402.0718

# %%
modelo_ar = ARIMA(serie_n, order = (7,0,0))
resultado = modelo_ar.fit()
print(resultado.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  456
# Model:                 ARIMA(7, 0, 0)   Log Likelihood                -689.661
# Date:                Tue, 19 Sep 2023   AIC                           1397.322
# Time:                        16:18:25   BIC                           1434.424
# Sample:                    01-31-1985   HQIC                          1411.937
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7753      0.035    136.208      0.000       4.707       4.844
# ar.L1          0.1488      0.044      3.420      0.001       0.064       0.234
# ar.L2          0.0826      0.049      1.679      0.093      -0.014       0.179
# ar.L3         -0.0934      0.051     -1.815      0.070      -0.194       0.007
# ar.L4         -0.1012      0.048     -2.099      0.036      -0.196      -0.007
# ar.L5         -0.1827      0.049     -3.711      0.000      -0.279      -0.086
# ar.L6         -0.2628      0.049     -5.359      0.000      -0.359      -0.167
# ar.L7         -0.2420      0.047     -5.123      0.000      -0.335      -0.149
# sigma2         1.1992      0.069     17.284      0.000       1.063       1.335
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                17.44
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.18   Skew:                            -0.27
# Prob(H) (two-sided):                  0.30   Kurtosis:                         3.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Análise dos Resíduos

# %%
residuos = resultado.resid
residuos.plot();

# %% [markdown]
# Média em torno do zero, com pouca tendência
#
# Resíduos bem concentrados, estáveis

# %% [markdown]
# #### Normalidade

# %%
stats.probplot(residuos, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %% [markdown]
# Graficamente, a série aparenta se aproximar de uma distribuição normal. Façamos o teste de Shapiro-Wilk para verificar:

# %%
e, p = stats.shapiro(residuos)
print(f'Estátistica de teste: {e:.4f}')
print(f'p-valor: {p:.4e}')
# Out:
# Estátistica de teste: 0.9882
# p-valor: 9.6014e-04

# %% [markdown]
# Isso indica que a distribuição dos resíduos **não é normal**

# %%
sns.distplot(residuos);
# Out:
# C:\Users\jahon\AppData\Local\Temp\ipykernel_3164\1081090613.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# #### Autocorrelação

# %% [markdown]
# Analisemos a autocorrelação dos resíduos usando ACF e PACF:

# %%
plot_acf(residuos, lags=20)
plt.show()

# %%
plot_pacf(residuos, lags=20)
plt.show()

# %% [markdown]
# Como todos os pontos de ambos os gráficos estão muito próximos do intervalo de confiança, concluímos que os resídios **não possuem autocorrelação**

# %%
fig = go.Figure()
_ = serie_n-residuos
fig.add_trace(go.Scatter(x=serie_n.index, y=serie_n.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=serie_n.index, y=_,
                    mode='lines',
                    name='Resíduos'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %% [markdown]
# ### Previsão

# %%
resultado.fittedvalues
# Out:
# 1985-01-31    4.775259
# 1985-02-28    5.232342
# 1985-03-31    5.511358
# 1985-04-30    5.444211
# 1985-05-31    4.271934
#                 ...
# 2022-08-31    3.470902
# 2022-09-30    4.304046
# 2022-10-31    5.219104
# 2022-11-30    5.962153
# 2022-12-31    6.044677
# Freq: M, Length: 456, dtype: float64

# %%
resultado.fittedvalues
previsao = resultado.predict(start=455, end=467)
_ = serie_n-residuos

fig = go.Figure()
fig.add_trace(go.Scatter(x=serie_n.index, y=serie_n.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=serie_n.index, y=_,
                    mode='lines',
                    name='Resíduos'))
fig.add_trace(go.Scatter(x=previsao.index, y=previsao,
                    mode='lines',
                    name='Previsão AR'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %% [markdown]
# O plot acima leva em consideração os dados transformados (raiz cúbica). Vamos plotar e guardar a previsão em seus valores originais:

# %%
prev_escala = pd.DataFrame(previsao**3)
prev_escala.columns = ['Modelo_AR']
prev_escala
# Out:
#              Modelo_AR
# 2022-12-31  220.861124
# 2023-01-31  244.711105
# 2023-02-28  212.495039
# 2023-03-31  134.824453
# 2023-04-30   84.096060
# 2023-05-31   63.185530
# 2023-06-30   49.186479
# 2023-07-31   49.778316
# 2023-08-31   59.255553
# 2023-09-30   86.892739
# 2023-10-31  127.212170
# 2023-11-30  164.920456
# 2023-12-31  185.854097

# %% [markdown]
# Agora, o plot com os dados corrigidos:

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=serie.index, y=serie.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=prev_escala.index, y=prev_escala['Modelo_AR'],
                    mode='lines',
                    name='Previsão'))

# %% [markdown]
# **Problemas do modelo:**
# * resíduos não seguem uma distribuição normal

# %% [markdown]
# ## **Modelo MA**
#
# Modelo ARIMA: (p,d,q)
#
# Modelo MA: (0,0,q)
#
# O modelo de Média Móvel (MA) é uma abordagem importante na análise e previsão de séries temporais. Diferentemente do modelo AR (Auto-Regressivo), o modelo MA baseia-se na premissa de que **o valor atual de uma série temporal é influenciado por ruídos aleatórios ou erros residuais de previsões passadas.** Em um modelo MA, a previsão é feita calculando-se uma média ponderada desses erros residuais anteriores, onde a ordem do modelo, representada como MA(q), determina quantos períodos anteriores são considerados.

# %%
for q in range(1, 11):
    modelo_ma = ARIMA(serie_n, order = (0,0,q))
    teste = modelo_ma.fit()
    print(f'ARIMA(0,0,{q}) - AIC: {teste.aic:.4f}')
# Out:
# ARIMA(0,0,1) - AIC: 1617.1496
# ARIMA(0,0,2) - AIC: 1569.7491
# ARIMA(0,0,3) - AIC: 1564.5801
# ARIMA(0,0,4) - AIC: 1560.3805
# ARIMA(0,0,5) - AIC: 1551.8963
# ARIMA(0,0,6) - AIC: 1522.1238
# ARIMA(0,0,7) - AIC: 1487.2752
# ARIMA(0,0,8) - AIC: 1483.0080
# ARIMA(0,0,9) - AIC: 1484.8854
# ARIMA(0,0,10) - AIC: 1486.7897

# %% [markdown]
# O menor valor de AIC foi obtido com q = 8

# %%
modelo_ma = ARIMA(serie_n, order = (0,0,8))

# %%
resultado_ma = modelo_ma.fit()
print(resultado_ma.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  456
# Model:                 ARIMA(0, 0, 8)   Log Likelihood                -731.504
# Date:                Tue, 19 Sep 2023   AIC                           1483.008
# Time:                        16:18:31   BIC                           1524.233
# Sample:                    01-31-1985   HQIC                          1499.247
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7810      0.027    179.646      0.000       4.729       4.833
# ma.L1          0.3085      0.049      6.300      0.000       0.213       0.405
# ma.L2          0.2319      0.049      4.737      0.000       0.136       0.328
# ma.L3         -0.0152      0.050     -0.305      0.760      -0.113       0.082
# ma.L4         -0.1136      0.048     -2.380      0.017      -0.207      -0.020
# ma.L5         -0.2231      0.048     -4.612      0.000      -0.318      -0.128
# ma.L6         -0.3253      0.048     -6.745      0.000      -0.420      -0.231
# ma.L7         -0.3322      0.049     -6.728      0.000      -0.429      -0.235
# ma.L8         -0.1166      0.050     -2.340      0.019      -0.214      -0.019
# sigma2         1.4441      0.091     15.910      0.000       1.266       1.622
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                31.46
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.20   Skew:                            -0.57
# Prob(H) (two-sided):                  0.25   Kurtosis:                         3.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Análise dos resíduos

# %%
residuos_ma = resultado_ma.resid
residuos_ma.plot()
plt.show()

# %% [markdown]
# Os resíduos aparentam ter uma média em torno de zero, com pouca tendência.

# %% [markdown]
# #### Normalidade

# %%
stats.probplot(residuos_ma, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
sns.distplot(residuos_ma);
# Out:
# C:\Users\jahon\AppData\Local\Temp\ipykernel_3164\656102450.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
e, p = stats.shapiro(residuos_ma)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 0.9808076024055481
# p-valor: 9.943053555616643e-06

# %% [markdown]
# Os resíduos **não seguem uma distribuição normal**

# %% [markdown]
# #### Autocorrelação

# %%
plot_acf(residuos_ma, lags=30)
plt.show()

# %%
plot_pacf(residuos_ma, lags=30)
plt.show()

# %% [markdown]
# Verificando os gráficos do ACF e do PACF, notamos que alguns valores estão fora do intervalo de confiança, apontando para a **existência de autocorrelação nos resíduos**, mesmo que fraca

# %%
fig = go.Figure()
_ = serie_n-residuos_ma
fig.add_trace(go.Scatter(x=serie_n.index, y=serie_n.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=serie_n.index, y=_,
                    mode='lines',
                    name='Resíduos'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %% [markdown]
# ### Previsão

# %%
resultado_ma.fittedvalues
previsao_ma = resultado_ma.predict(start=455, end=467)

fig = go.Figure()
fig.add_trace(go.Scatter(x=serie_n.index, y=serie_n.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=serie_n.index, y=_,
                    mode='lines',
                    name='Resíduos MA'))
fig.add_trace(go.Scatter(x=previsao_ma.index, y=previsao_ma,
                    mode='lines',
                    name='Previsão MA'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %%
prev_escala['Modelo_MA'] = previsao_ma**3
prev_escala.head()
# Out:
#              Modelo_AR   Modelo_MA
# 2022-12-31  220.861124  173.613405
# 2023-01-31  244.711105  185.384784
# 2023-02-28  212.495039  171.885718
# 2023-03-31  134.824453  126.449308
# 2023-04-30   84.096060  103.787111

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=serie.index, y=serie.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=prev_escala.index, y=prev_escala['Modelo_MA'],
                    mode='lines',
                    name='Previsão'))

# %% [markdown]
# **Problemas do modelo:**
# * resíduos não seguem uma distribuição normal
# * autocorrelação dos resíduos

# %% [markdown]
# ## **Modelo ARMA**
#
# Modelo ARIMA: (p,d,q)
#
# Modelo ARMA: (p,0,q)
#
#
# O modelo ARMA combina um componente autoregressivo (AR), que tenta explicar **a influência dos valores passados na série atual** com um componente de média móvel (MA), **que tenta capturar os erros das previsões passadas.**

# %%
modelo_arma = ARIMA(serie_n, order = (7,0,1))
resultado_arma = modelo_arma.fit()
print(resultado_arma.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  456
# Model:                 ARIMA(7, 0, 1)   Log Likelihood                -689.139
# Date:                Tue, 19 Sep 2023   AIC                           1398.279
# Time:                        16:18:34   BIC                           1439.504
# Sample:                    01-31-1985   HQIC                          1414.518
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7755      0.033    143.528      0.000       4.710       4.841
# ar.L1          0.3106      0.204      1.521      0.128      -0.090       0.711
# ar.L2          0.0457      0.066      0.697      0.486      -0.083       0.174
# ar.L3         -0.1154      0.061     -1.900      0.057      -0.234       0.004
# ar.L4         -0.0891      0.054     -1.645      0.100      -0.195       0.017
# ar.L5         -0.1692      0.054     -3.134      0.002      -0.275      -0.063
# ar.L6         -0.2276      0.068     -3.357      0.001      -0.361      -0.095
# ar.L7         -0.1917      0.085     -2.255      0.024      -0.358      -0.025
# ma.L1         -0.1727      0.200     -0.863      0.388      -0.565       0.219
# sigma2         1.1964      0.070     17.117      0.000       1.059       1.333
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                16.55
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.17   Skew:                            -0.26
# Prob(H) (two-sided):                  0.33   Kurtosis:                         3.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Análise dos resíduos

# %%
residuos_arma = resultado_arma.resid
residuos_arma.plot()
plt.show()

# %% [markdown]
# Os resíduos aparentam ter uma média em torno de zero, com pouca tendência.

# %% [markdown]
# #### Normalidade

# %%
stats.probplot(residuos_arma, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
sns.distplot(residuos_arma);
# Out:
# C:\Users\jahon\AppData\Local\Temp\ipykernel_3164\3134224917.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
e, p = stats.shapiro(residuos_arma)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 0.9884341955184937
# p-valor: 0.0011298784520477057

# %% [markdown]
# O valor está próximo do limite do teste de hipótese e o gráfico se comporta de maneira similar ao de uma distribuição normal, mas os resíduos **não seguem uma distribuição normal**.

# %% [markdown]
# #### Autocorrelação

# %%
plot_acf(residuos_arma, lags=30)
plt.show()

# %%
plot_pacf(residuos_arma, lags=30)
plt.show()

# %% [markdown]
# Verificando os gráficos do ACF e do PACF, notamos que alguns valores estão fora do intervalo de confiança, apontando para a **existência de autocorrelação nos resíduos**, mesmo que fraca

# %%
fig = go.Figure()
_ = serie_n-residuos_arma

fig.add_trace(go.Scatter(x=serie_n.index, y=serie_n.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=serie_n.index, y=_,
                    mode='lines',
                    name='Resíduos'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %% [markdown]
# ### Previsão

# %%
resultado_arma.fittedvalues
# Out:
# 1985-01-31    4.775465
# 1985-02-28    5.232455
# 1985-03-31    5.511463
# 1985-04-30    5.444321
# 1985-05-31    4.271997
#                 ...
# 2022-08-31    3.478114
# 2022-09-30    4.263505
# 2022-10-31    5.240852
# 2022-11-30    5.921760
# 2022-12-31    6.088112
# Freq: M, Length: 456, dtype: float64

# %%
previsao_arma = resultado_arma.predict(start=455, end=467)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=serie_n.index, y=serie_n.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=serie_n.index, y=_,
                    mode='lines',
                    name='Resíduos'))
fig.add_trace(go.Scatter(x=previsao_arma.index, y=previsao_arma,
                    mode='lines',
                    name='Previsão ARMA'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %%
prev_escala['Modelo_ARMA'] = previsao_arma**3
prev_escala.head()
# Out:
#              Modelo_AR   Modelo_MA  Modelo_ARMA
# 2022-12-31  220.861124  173.613405   225.656492
# 2023-01-31  244.711105  185.384784   244.946575
# 2023-02-28  212.495039  171.885718   211.868115
# 2023-03-31  134.824453  126.449308   139.849745
# 2023-04-30   84.096060  103.787111    86.817153

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=serie.index, y=serie.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=prev_escala.index, y=prev_escala['Modelo_ARMA'],
                    mode='lines',
                    name='Previsão'))

# %% [markdown]
# **Problemas do modelo:**
# * resíduos não seguem uma distribuição normal
# * autocorrelação dos resíduos

# %% [markdown]
# ## **Modelo ARIMA**
#
# Modelo ARIMA: (p,d,q)

# %% [markdown]
# O modelo preditivo ARIMA é uma extensão do modelo ARMA, amplamente utilizado para modelar e prever séries temporais. O ARIMA é especialmente **útil quando a série temporal apresenta tendências temporais e/ou sazonalidades que não podem ser adequadamente capturadas por um modelo ARMA simples.**
#
# O modelo possui três componentes: **o componente autorregressivo (AR), o componente de média móvel (MA) e o componente de integração (I).**

# %%
modelo_arima = ARIMA(serie_n, order = (7,1,1))
resultado_arima = modelo_arima.fit()
print(resultado_arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  456
# Model:                 ARIMA(7, 1, 1)   Log Likelihood                -692.205
# Date:                Tue, 19 Sep 2023   AIC                           1402.411
# Time:                        16:18:37   BIC                           1439.493
# Sample:                    01-31-1985   HQIC                          1417.020
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1504      0.044      3.422      0.001       0.064       0.237
# ar.L2          0.0833      0.049      1.688      0.091      -0.013       0.180
# ar.L3         -0.0933      0.052     -1.784      0.074      -0.196       0.009
# ar.L4         -0.1010      0.049     -2.065      0.039      -0.197      -0.005
# ar.L5         -0.1825      0.049     -3.737      0.000      -0.278      -0.087
# ar.L6         -0.2620      0.047     -5.567      0.000      -0.354      -0.170
# ar.L7         -0.2403      0.047     -5.061      0.000      -0.333      -0.147
# ma.L1         -1.0000      1.652     -0.605      0.545      -4.238       2.238
# sigma2         1.2019      1.990      0.604      0.546      -2.699       5.103
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                19.40
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.18   Skew:                            -0.27
# Prob(H) (two-sided):                  0.30   Kurtosis:                         3.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Análise dos resíduos

# %%
residuos_arima = resultado_arima.resid
residuos_arima.plot()
plt.show;

# %% [markdown]
# Os resíduos aparentam ter uma média em torno de zero, com pouca tendência.

# %% [markdown]
# #### Normalidade

# %%
stats.probplot(residuos_arima, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
sns.distplot(residuos_arima);
# Out:
# C:\Users\jahon\AppData\Local\Temp\ipykernel_3164\2354701122.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Graficamente, os resíduos se aproximam de uma gaussiana. Façamos o teste de hipóteses:

# %%
e, p = stats.shapiro(residuos_arima)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Out:
# Estatística de teste: 0.9801571369171143
# p-valor: 6.9335683292592876e-06

# %% [markdown]
# Os resíduos **não seguem uma distribuição normal**

# %% [markdown]
# #### Autocorrelação

# %%
plot_acf(residuos_arima, lags=30)
plt.show()

# %%
plot_pacf(residuos_arima, lags=30)
plt.show()

# %% [markdown]
# Os gráficos apontam que os resíduos possuem uma **autocorrelação muito fraca**, com poucos valores levemente fora do intervalo de confiança.

# %%
fig = go.Figure()
_ = serie_n-residuos_arima
fig.add_trace(go.Scatter(x=serie_n.index, y=serie_n.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=serie_n.index, y=_,
                    mode='lines',
                    name='Resíduos ARIMA'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %% [markdown]
# ### Previsão

# %%
resultado_arima.fittedvalues
previsao_arima = resultado_arima.predict(start=455, end=467)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=serie_n.index, y=serie_n.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=serie_n.index, y=_,
                    mode='lines',
                    name='Resíduos ARIMA'))
fig.add_trace(go.Scatter(x=previsao_arma.index, y=previsao_arma,
                    mode='lines',
                    name='Previsão ARIMA'))
fig.update_layout(title='Série histórica de chuvas mensais em São Paulo',
                    xaxis_title='Anos',
                    yaxis_title='Chuvas (mm)')
fig.show()

# %%
prev_escala['Modelo_ARIMA'] = previsao_arima**3
prev_escala.head()
# Out:
#              Modelo_AR   Modelo_MA  Modelo_ARMA  Modelo_ARIMA
# 2022-12-31  220.861124  173.613405   225.656492    220.801167
# 2023-01-31  244.711105  185.384784   244.946575    244.510804
# 2023-02-28  212.495039  171.885718   211.868115    212.235283
# 2023-03-31  134.824453  126.449308   139.849745    134.879826
# 2023-04-30   84.096060  103.787111    86.817153     84.257192

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=serie.index, y=serie.values,
                    mode='lines',
                    name='Série histórica'))
fig.add_trace(go.Scatter(x=prev_escala.index, y=prev_escala['Modelo_ARIMA'],
                    mode='lines',
                    name='Previsão'))

# %% [markdown]
# **Problemas do modelo:**
# * resíduos não seguem uma distribuição normal

# %% [markdown]
# ## **Modelo AutoARIMA**
#
# Modelo ARIMA: (p,d,q)
#
# Modeo SARIMA: (p,d,q)(P,D,Q)
#
# O modelo AutoARIMA considera os componentes do modelo ARIMA + os componente de sazonalidade do modelo SARIMA, sendo o mais completo dentre os apresentados.
# Uma das grandes vantagens do modelo AutoARIMA é, além de considerar a sazonalidade, a automatização da busca pelos melhores parâmetros.

# %%
from pmdarima.arima import auto_arima

# %%
## Buscando o melhor arranjo de parâmetros para o modelo AutoARIMA

modelo_auto = auto_arima(serie_n, trace=True, stepwise=False, seasonal=True,
                         max_p=10, max_q=10, max_P=4, max_Q=4,
                         start_p=0, start_q=0, start_P=0, start_Q=0, m=12)
                        
## trace: imprime o resultado de cada iteração
## stepwise: realiza a busca de forma mais rápida
## seasonal: considerar ou não a sazonalidade
## m: período da sazonalidade (mensal)
# Out:
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=1706.485, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=1584.768, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=1551.907, Time=0.57 sec
#  ARIMA(0,0,0)(0,0,3)[12] intercept   : AIC=1510.722, Time=2.52 sec
#  ARIMA(0,0,0)(0,0,4)[12] intercept   : AIC=1490.439, Time=3.43 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=1501.286, Time=0.58 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.59 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=4.79 sec
#  ARIMA(0,0,0)(1,0,3)[12] intercept   : AIC=1329.130, Time=10.51 sec
#  ARIMA(0,0,0)(1,0,4)[12] intercept   : AIC=inf, Time=20.43 sec
#  ARIMA(0,0,0)(2,0,0)[12] intercept   : AIC=1454.076, Time=2.98 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=5.91 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=1362.366, Time=5.51 sec
#  ARIMA(0,0,0)(2,0,3)[12] intercept   : AIC=1338.810, Time=5.78 sec
#  ARIMA(0,0,0)(3,0,0)[12] intercept   : AIC=inf, Time=5.53 sec
#  ARIMA(0,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=8.35 sec
#  ARIMA(0,0,0)(3,0,2)[12] intercept   : AIC=inf, Time=7.65 sec
#  ARIMA(0,0,0)(4,0,0)[12] intercept   : AIC=inf, Time=8.59 sec
#  ARIMA(0,0,0)(4,0,1)[12] intercept   : AIC=1808.825, Time=5.82 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=1617.150, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=1544.994, Time=0.28 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=1526.214, Time=0.59 sec
#  ARIMA(0,0,1)(0,0,3)[12] intercept   : AIC=1492.856, Time=1.95 sec
#  ARIMA(0,0,1)(0,0,4)[12] intercept   : AIC=1477.825, Time=2.97 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=1494.229, Time=0.46 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.47 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=3.43 sec
#  ARIMA(0,0,1)(1,0,3)[12] intercept   : AIC=1348.376, Time=7.70 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=1452.965, Time=1.35 sec
#  ARIMA(0,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=2.42 sec
#  ARIMA(0,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=4.23 sec
#  ARIMA(0,0,1)(3,0,0)[12] intercept   : AIC=1402.267, Time=4.52 sec
#  ARIMA(0,0,1)(3,0,1)[12] intercept   : AIC=2037.400, Time=3.35 sec
#  ARIMA(0,0,1)(4,0,0)[12] intercept   : AIC=1678.174, Time=5.65 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=1569.749, Time=0.12 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : AIC=1515.985, Time=0.33 sec
#  ARIMA(0,0,2)(0,0,2)[12] intercept   : AIC=1502.628, Time=0.77 sec
#  ARIMA(0,0,2)(0,0,3)[12] intercept   : AIC=1475.774, Time=2.28 sec
#  ARIMA(0,0,2)(1,0,0)[12] intercept   : AIC=1482.921, Time=0.60 sec
#  ARIMA(0,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.72 sec
#  ARIMA(0,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=4.38 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=1449.456, Time=1.53 sec
#  ARIMA(0,0,2)(2,0,1)[12] intercept   : AIC=inf, Time=2.88 sec
#  ARIMA(0,0,2)(3,0,0)[12] intercept   : AIC=1402.523, Time=4.43 sec
#  ARIMA(0,0,3)(0,0,0)[12] intercept   : AIC=1564.580, Time=0.17 sec
#  ARIMA(0,0,3)(0,0,1)[12] intercept   : AIC=1516.308, Time=0.33 sec
#  ARIMA(0,0,3)(0,0,2)[12] intercept   : AIC=1504.379, Time=0.82 sec
#  ARIMA(0,0,3)(1,0,0)[12] intercept   : AIC=1484.431, Time=0.65 sec
#  ARIMA(0,0,3)(1,0,1)[12] intercept   : AIC=inf, Time=1.99 sec
#  ARIMA(0,0,3)(2,0,0)[12] intercept   : AIC=1447.300, Time=1.78 sec
#  ARIMA(0,0,4)(0,0,0)[12] intercept   : AIC=1560.380, Time=0.18 sec
#  ARIMA(0,0,4)(0,0,1)[12] intercept   : AIC=1518.235, Time=0.43 sec
#  ARIMA(0,0,4)(1,0,0)[12] intercept   : AIC=1484.015, Time=0.84 sec
#  ARIMA(0,0,5)(0,0,0)[12] intercept   : AIC=1551.896, Time=0.29 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=1577.908, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=1527.510, Time=0.25 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=1514.621, Time=0.63 sec
#  ARIMA(1,0,0)(0,0,3)[12] intercept   : AIC=1485.655, Time=1.95 sec
#  ARIMA(1,0,0)(0,0,4)[12] intercept   : AIC=1473.249, Time=3.37 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=1491.019, Time=0.52 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=2.55 sec
#  ARIMA(1,0,0)(1,0,3)[12] intercept   : AIC=1330.466, Time=6.00 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=1452.320, Time=1.55 sec
# c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\pmdarima\arima\_auto_solvers.py:524: ModelFitWarning:
#
# Error fitting  ARIMA(1,0,0)(2,0,1)[12] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\pmdarima\arima\_auto_solvers.py", line 508, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\pmdarima\arima\arima.py", line 603, in fit
#     self._fit(y, X, **fit_args)
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\pmdarima\arima\arima.py", line 524, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\pmdarima\arima\arima.py", line 510, in _fit_wrapper
#     fitted = arima.fit(
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 704, in fit
#     mlefit = super(MLEModel, self).fit(start_params, method=method,
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py", line 566, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\optimizer.py", line 242, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\optimizer.py", line 659, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_lbfgsb_py.py", line 199, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_lbfgsb_py.py", line 362, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 285, in fun_and_grad
#     self._update_fun()
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 251, in _update_fun
#     self._update_fun_impl()
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 155, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py", line 534, in f
#     return -self.loglike(params, *args) / nobs
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 939, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 1001, in loglike
#     kfilter = self._filter(**kwargs)
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 921, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "c:\Users\jahon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\representation.py", line 1058, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels\tsa\statespace\_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels\tsa\statespace\_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels\tsa\statespace\_tools.pyx", line 1525, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=nan sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=1344.484, Time=3.74 sec
#  ARIMA(1,0,0)(3,0,0)[12] intercept   : AIC=inf, Time=5.19 sec
#  ARIMA(1,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=8.15 sec
#  ARIMA(1,0,0)(4,0,0)[12] intercept   : AIC=inf, Time=12.03 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=1579.401, Time=0.14 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=1527.555, Time=0.21 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=1514.301, Time=0.90 sec
#  ARIMA(1,0,1)(0,0,3)[12] intercept   : AIC=1485.613, Time=3.13 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=1491.235, Time=0.85 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.51 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=3.67 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=1458.076, Time=1.69 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=3.20 sec
#  ARIMA(1,0,1)(3,0,0)[12] intercept   : AIC=1406.169, Time=4.53 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=1564.206, Time=0.27 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=1516.544, Time=0.95 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=1504.417, Time=3.17 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=1484.634, Time=2.07 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=2.48 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=1449.534, Time=4.41 sec
#  ARIMA(1,0,3)(0,0,0)[12] intercept   : AIC=1564.835, Time=0.28 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=1518.293, Time=0.62 sec
#  ARIMA(1,0,3)(1,0,0)[12] intercept   : AIC=1483.483, Time=1.11 sec
#  ARIMA(1,0,4)(0,0,0)[12] intercept   : AIC=1533.459, Time=1.29 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=1578.846, Time=0.24 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=1525.261, Time=0.36 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=1511.368, Time=0.92 sec
#  ARIMA(2,0,0)(0,0,3)[12] intercept   : AIC=1482.880, Time=3.27 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=1488.459, Time=0.87 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.93 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=3.14 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=1451.872, Time=2.13 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=3.76 sec
#  ARIMA(2,0,0)(3,0,0)[12] intercept   : AIC=inf, Time=5.78 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=1577.838, Time=0.54 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=inf, Time=1.29 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=1518.586, Time=2.05 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=1493.839, Time=1.29 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.67 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=1453.523, Time=2.58 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.80 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=1337.584, Time=2.05 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=1484.321, Time=1.81 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=1381.447, Time=0.83 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=1548.796, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=1510.077, Time=0.46 sec
#  ARIMA(3,0,0)(0,0,2)[12] intercept   : AIC=1499.522, Time=1.29 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=1482.390, Time=1.03 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=1447.420, Time=2.71 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=1450.063, Time=0.50 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=1439.856, Time=1.53 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=1452.372, Time=2.17 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=1569.979, Time=0.78 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=1515.720, Time=0.20 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=1491.171, Time=0.54 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=1476.942, Time=1.00 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=1434.149, Time=0.79 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=1468.417, Time=0.43 sec
#
# Best model:  ARIMA(0,0,0)(1,0,3)[12] intercept
# Total fit time: 308.203 seconds

# %% [markdown]
# Os parâmetros escolhidos pelo modelo foram ARIMA(0,0,0)(1,0,3).

# %%
print(modelo_auto.aic())
# Out:
# 1329.1300638898294

# %%
resultado_auto = modelo_auto.fit(serie_n)
print(resultado_auto.summary())
# Out:
#                                     SARIMAX Results
# ========================================================================================
# Dep. Variable:                                y   No. Observations:                  456
# Model:             SARIMAX(1, 0, [1, 2, 3], 12)   Log Likelihood                -658.565
# Date:                          Tue, 19 Sep 2023   AIC                           1329.130
# Time:                                  16:56:44   BIC                           1353.865
# Sample:                              01-31-1985   HQIC                          1338.874
#                                    - 12-31-2022
# Covariance Type:                            opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0320      0.020      1.565      0.118      -0.008       0.072
# ar.S.L12       0.9931      0.004    224.007      0.000       0.984       1.002
# ma.S.L12      -0.9313      0.046    -20.198      0.000      -1.022      -0.841
# ma.S.L24      -0.0777      0.064     -1.207      0.228      -0.204       0.049
# ma.S.L36       0.1224      0.049      2.483      0.013       0.026       0.219
# sigma2         1.0265      0.066     15.605      0.000       0.898       1.155
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.49   Jarque-Bera (JB):                29.36
# Prob(Q):                              0.22   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                            -0.44
# Prob(H) (two-sided):                  0.48   Kurtosis:                         3.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Análise dos resíduos

# %%
print("oi")
# Out:
# oi

# %%
residuos_auto = resultado_auto.resid
residuos_auto()
# Out:
# 1985-01-31    1.033401
# 1985-02-28    1.575804
# 1985-03-31    1.463334
# 1985-04-30   -0.770595
# 1985-05-31    0.352358
#                 ...
# 2022-08-31    0.315427
# 2022-09-30    1.047423
# 2022-10-31    0.021396
# 2022-11-30    0.576018
# 2022-12-31   -0.187350
# Freq: M, Length: 456, dtype: float64

# %%
plt.plot(residuos_auto())
plt.show();

# %% [markdown]
# #### Normalidade

# %% [markdown]
# #### Autocorrelação

# %% [markdown]
# #### Previsão
